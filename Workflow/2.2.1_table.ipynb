# %%
import pandas as pd
import numpy
from __future__ import division

# %%
df2_WS1T = pd.read_csv("/Users/asteriag/Desktop/DATASCIENCEPROJECT_WORKFLOW/pythonProject/segment2_WS1_has_duration.csv")

# %%
df2_WS1T.head(n=1)
# Out:
#                 CASE_ID WRKFLW_TSK_MAP_GROUPED WRKFLW_TSK_MAP_DETAILED  \
# 0  914197|528561|809459                 Submit                  Submit
#
#        PATH_CRDATETIME ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER  \
# 0  27/10/2019 21:11:07      914197                    NaN            16
#
#   LATEST_STATUS        WRKFLW_PROCESS                        QUERY_PART  ...  \
# 0             N  1. App to Assessment  Part 1 - Application ID Workflow  ...
#
#   SPK_CAT_TYPE_CD  BROAD_COURSE_LEVEL   DEGREETYPE  \
# 0             MCW                HDCW  Full Degree
#
#    LIABILITY_CATEGORY_CD_RECODE  ORIG_LIABILITY_CATEGORY_CD_RECODE  \
# 0                            AS                                 AS
#
#   OFFER_RELEASED_FG OFFER_OUTCOME_CD OFFER_CONDITIONS  \
# 0                 Y             $DEC                N
#
#                           time_used_str  time_used_second
# 0  1 days 10 hours 30 minutes 4 seconds          124204.0
#
# [1 rows x 58 columns]

# %%
numOfWorkflowProcesses = df2_WS1T.groupby('CASE_ID').CASE_ID.count()

count_dic=dict()
for i,v in numOfWorkflowProcesses.items():
    if count_dic.get(v) is None:
        count_dic[v]=[]
        count_dic[v].append(i)
    else:
        count_dic[v].append(i)
#count_dic

# %%
len_list=[]
for key in count_dic.keys():
    len_list.append(len(count_dic[key]))
print(count_dic)
# Out:
# {1: ['1019640|358567|558907', '1026395|472249|724849', '1029607|371968|580044', '1033961|377264|587916', '1033961|377264|587918', '1046452|393095|611909', '1058775|412225|639064', '1058775|412225|639065', '1058775|412225|639066', '1063477|430839|667247', '1069710|428115|663295', '1069710|428121|663304', '1069710|428124|663307', '1079333|441314|682214', '1088716|452585|695500', '1093979|459864|706332', '1093979|459864|706333', '1098455|466620|716817', '1098520|465632|715306', '1098520|465632|715307', '1104517|472932|725814', '1122226|496943|763162', '1122226|496950|763173', '1122810|493886|758501', '1128144|501548|769828', '1128144|501548|769829', '1135096|528430|809258', '1138310|515217|790114', '1147689|528680|809625', '1149186|583618|886120', '1149940|532731|815150', '1150681|547985|838796', '1150681|547985|838797', '1150681|547985|838798', '1150681|547985|838799', '1150846|533981|817249', '1150846|534008|817290', '1150846|534019|817307', '1153021|537208|822177', '1153021|537208|822178', '1154289|539079|824971', '1154289|539629|825814', '1154979|540393|826957', '1159304|546815|837084', '1159304|546815|837085', '1160875|549131|840304', '1162563|551530|843836', '1162781|551809|844207', '1163186|552473|845192', '1163186|552473|845193', '1163630|553129|846132', '1163704|553231|846257', '1163704|553231|846258', '1163704|553231|846259', '1165176|555670|849834', '1165176|555670|849835', '1165176|555670|849836', '1174873|567719|865615', '1174873|567728|865624', '1175470|568589|866847', '1177073|570614|869660', '1177117|570665|869732', '1177161|570722|869803', '1177591|571267|870521', '1177989|571742|871248', '1180072|574467|874893', '1180075|581200|882774', '1184144|580372|881723', '1185680|583011|885272', '1186079|582893|885119', '1186350|583256|885602', '1187437|585024|887881', '1187786|585429|888479', '1187902|585577|888686', '1188027|585737|888918', '692283|585118|888016', '904396|583563|886042'], 2: ['1009756|386701|602178', '1021239|404259|627179', '1025997|453030|696147', '1048850|396182|616547', '1061373|553479|846638', '1071249|431714|668608', '1076583|437721|676609', '1078019|473686|726884', '1078511|440234|680577', '1078511|440234|680578', '1092880|458345|703933', '1106442|474944|728715', '1106442|474944|728716', '1115267|484875|744175', '1115267|484875|744204', '1121166|556107|850456', '1129852|508725|780624', '1131729|507215|778260', '1143372|522188|800537', '1143467|555714|849903', '1144272|538586|824284', '1144272|541940|829405', '1155787|545505|835209', '1163281|552606|845367', '1163997|553696|846942', '1164393|554321|847862', '1165102|555549|849654', '1186116|583000|885258', '1186153|583290|885658', '269360|487371|748314', '269360|487371|748315', '360298|510130|782700', '381632|463894|712585', '551017|366660|572143', '551017|366660|572144', '693876|555710|849894', '693876|555710|849895', '694040|554173|847650', '757143|409230|679666', '758073|497032|763298', '758073|497032|763412', '760625|420635|651867', '762731|427348|662225', '766492|543478|831915', '768023|450020|691672', '790571|560167|856977', '790571|560167|856978', '790571|560167|856979', '790571|560167|856980', '831549|553088|846078', '831865|422285|653978', '834960|423906|656399', '836937|554464|848091', '837735|422153|653782', '864689|423206|660919', '875015|433759|671648', '875015|433759|671691', '911318|553440|846579'], 3: ['1059768|432916|670310', '1089677|479341|735255', '1089677|479341|735256', '1091180|456139|700520', '1108227|554014|847440', '1108520|478011|733307', '1125095|531336|813247', '1125095|531336|813248', '1155097|546559|836709', '1165033|555413|849440', '1165033|555413|849442', '1165033|555413|849443', '1176328|569713|868467', '1176328|569738|868498', '381632|530018|811647', '595995|412855|639997', '669375|407240|631606', '692283|585118|888015', '758966|360139|561449', '816823|362198|564672', '832643|484615|743795', '836048|428711|664195', '855827|408156|633032', '886776|417211|646766', '935028|237355|377891'], 4: ['1015387|353470|551267 ...

# %%
def strfdelta(tdelta, fmt):
    d=dict()
    d["days"],rem1 = divmod(tdelta,60*60*24)
    d["hours"], rem2 = divmod(rem1, 3600)
    d["minutes"], d["seconds"] = divmod(rem2, 60)
    return fmt.format(**d)

# %%
list_avgtime_per_key =[]
for key in count_dic.keys():
    id_list = count_dic[key]
    list_sumtime_person = 0
    for id in id_list:
        df = df2_WS1T[df2_WS1T['CASE_ID']== id]
        tsum = df['time_used_second'].sum()
        list_sumtime_person+=tsum
    list_avgtime_per_key.append(int((list_sumtime_person/len(count_dic[key]))))

list_avgtime_per_key_str = []
for i in list_avgtime_per_key:
    list_avgtime_per_key_str.append(strfdelta(i,"{days} days {hours} hours {minutes} minutes {seconds} seconds"))

# %%
list_mediantime_per_key = []
for key in count_dic.keys():
    id_list = count_dic[key]
    list_sumtime_per_person = []
    for id in id_list:
        df = df2_WS1T[df2_WS1T['CASE_ID']== id]
        tsum = df['time_used_second'].sum()
        list_sumtime_per_person.append(tsum)
    list_mediantime_per_key.append(numpy.median(list_sumtime_per_person))

list_mediantime_per_key_str = []
for i in list_mediantime_per_key:
    list_mediantime_per_key_str.append(strfdelta(i,"{days} days {hours} hours {minutes} minutes {seconds} seconds"))

# %%
list_percent_reach_end = []
for key in count_dic.keys():
    id_list = count_dic[key]
    count_df_end_step = 0
    count_df_id = 0
    for id in id_list:
        df_id = df2_WS1T[df2_WS1T['CASE_ID']== id]
        df_end_step = df_id[df_id['WRKFLW_TSK_MAP_GROUPED']=='Send for Assessment']
        count_df_id += df_id['CASE_ID'].count()
        count_df_end_step += df_end_step['CASE_ID'].count()
    list_percent_reach_end.append(str(round((count_df_end_step/count_df_id)*100,2))+ "%")

# %%
list_step_per_key = []
for key in count_dic.keys():
    id_list = count_dic[key]
    list_step = set()
    for id in id_list:
        df = df2_WS1T[df2_WS1T['CASE_ID']== id]
        for index, row in df.iterrows():
            list_step.add(row['WRKFLW_TSK_MAP_GROUPED'])
    list_step_per_key.append(list_step)

# %%
s2_t1=pd.DataFrame({'Number of Workflow processes in this Workflow Segment':count_dic.keys(),'Number of cases':len_list, 'average time for workflow segment':list_avgtime_per_key_str,'median time for workflow segment':list_mediantime_per_key_str,'percentage of cases reaching to end of workflow segment':list_percent_reach_end,'step':list_step_per_key})
s2_t1.head(n=10)
# Out:
#    Number of Workflow processes in this Workflow Segment  Number of cases  \
# 0                                                  1                   77
# 1                                                  2                   58
# 2                                                  3                   25
# 3                                                  4                  100
# 4                                                  5                  140
# 5                                                  6                  289
# 6                                                  7                  456
# 7                                                  8                  391
# 8                                                  9                  198
# 9                                                 10                  128
#
#         average time for workflow segment  \
# 0      0 days 0 hours 0 minutes 0 seconds
# 1   9 days 10 hours 48 minutes 32 seconds
# 2   16 days 8 hours 43 minutes 32 seconds
# 3   13 days 2 hours 25 minutes 34 seconds
# 4    15 days 4 hours 44 minutes 4 seconds
# 5   13 days 8 hours 44 minutes 43 seconds
# 6  11 days 23 hours 13 minutes 19 seconds
# 7   12 days 5 hours 35 minutes 47 seconds
# 8  18 days 11 hours 18 minutes 24 seconds
# 9  16 days 23 hours 59 minutes 46 seconds
#
#                 median time for workflow segment  \
# 0     0.0 days 0.0 hours 0.0 minutes 0.0 seconds
# 1  0.0 days 22.0 hours 18.0 minutes 19.5 seconds
# 2  7.0 days 19.0 hours 24.0 minutes 56.0 seconds
# 3   9.0 days 22.0 hours 0.0 minutes 24.0 seconds
# 4    9.0 days 3.0 hours 7.0 minutes 38.5 seconds
# 5    7.0 days 2.0 hours 9.0 minutes 36.0 seconds
# 6   7.0 days 4.0 hours 10.0 minutes 42.0 seconds
# 7  6.0 days 11.0 hours 53.0 minutes 43.0 seconds
# 8    12.0 days 8.0 hours 5.0 minutes 6.0 seconds
# 9  13.0 days 0.0 hours 53.0 minutes 18.5 seconds
#
#   percentage of cases reaching to end of workflow segment  \
# 0                                               0.0%
# 1                                             38.79%
# 2                                             22.67%
# 3                                             19.75%
# 4                                             18.43%
# 5                                             15.63%
# 6                                             13.69%
# 7                                             11.92%
# 8                                             10.33%
# 9                                              9.45%
#
#                                                 step
# 0                                           {Submit}
# 1  {Send for Assessment, AR - Reviewed - advanced...
# 2  {Send for Assessment, AR - Created - previous ...
# 3  {Send for Assessment, AR - Not Satisfied - pre...
# 4  {Assessment Outcome - Higher Preference Succes...
# 5  {AR - Reviewed - advanced standing, Assessment...
# 6  {AR - Reviewed - advanced standing, AR - Reque...
# 7  {OC - Reviewed - Other, AR - Requested - sylla...
# 8  {OC - Reviewed - Other, AR - Requested - sylla...
# 9  {AR - Requested - syllabus, AR - Satisfied - a...

# %%
s2_t1.to_csv('segment2_WS1_table.csv', index=False)
