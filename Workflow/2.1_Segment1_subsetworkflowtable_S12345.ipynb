# %%
import pandas as pd
import csv
import numpy as np
from datetime import datetime

# %%
df1 = pd.read_csv("/Users/asteriag/Desktop/DATASCIENCEPROJECT_WORKFLOW/Workflow/workflow_segment1.csv")

# %%
df1.head(n=10)
# Out:
#                CASE_ID  WRKFLW_TSK_MAP_GROUPED WRKFLW_TSK_MAP_DETAILED  \
# 0  838396|92416|142450                  Submit                  Submit
# 1  838396|92416|142450                  Submit                  Submit
# 2  838396|92416|142450  Allow Workflow Restart  Allow Workflow Restart
# 3  838396|92416|142450                Finalise                Finalise
# 4  838396|92416|142450       Manage Acceptance       Manage Acceptance
# 5  838396|92416|142450                  Accept                  Accept
# 6  838396|92416|142450           Release Offer           Release Offer
# 7  838396|92416|142450  Restart Offer Workflow  Restart Offer Workflow
# 8  838396|92416|142450  Allow Workflow Restart  Allow Workflow Restart
# 9  838396|92416|142450                Finalise                Finalise
#
#       PATH_CRDATETIME ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER  \
# 0    4/7/2019 9:49:26      654385                    NaN             1
# 1    4/7/2019 9:49:23  $TB.DPUSER                    NaN             2
# 2  18/2/2019 12:17:24   MAHARJANS      Academic Services             3
# 3  18/2/2019 12:17:13   MAHARJANS      Academic Services             4
# 4  18/2/2019 12:16:18   MAHARJANS      Academic Services             5
# 5  18/2/2019 12:16:11   MAHARJANS      Academic Services             6
# 6  18/2/2019 12:14:52   MAHARJANS      Academic Services             7
# 7  18/2/2019 12:14:08       ELLAO      Academic Services             8
# 8  18/2/2019 11:56:33       ELLAO      Academic Services             9
# 9  18/2/2019 11:56:27       ELLAO      Academic Services            10
#
#   LATEST_STATUS        WRKFLW_PROCESS                             QUERY_PART  \
# 0             Y  1. App to Assessment       Part 1 - Application ID Workflow
# 1             N  1. App to Assessment       Part 1 - Application ID Workflow
# 2             N         4. Post offer  Part 2 - Application Line ID Workflow
# 3             N         4. Post offer  Part 2 - Application Line ID Workflow
# 4             N         4. Post offer  Part 2 - Application Line ID Workflow
# 5             N         4. Post offer  Part 2 - Application Line ID Workflow
# 6             N         4. Post offer  Part 2 - Application Line ID Workflow
# 7             N         4. Post offer  Part 2 - Application Line ID Workflow
# 8             N         4. Post offer  Part 2 - Application Line ID Workflow
# 9             N         4. Post offer  Part 2 - Application Line ID Workflow
#
#    ... ORIG_SPRD_CD       ORIG_SPRD_NM  SPK_CAT_TYPE_CD  BROAD_COURSE_LEVEL  \
# 0  ...         STYI  Start Year Intake              MCW                HDCW
# 1  ...         STYI  Start Year Intake              MCW                HDCW
# 2  ...         STYI  Start Year Intake              MCW                HDCW
# 3  ...         STYI  Start Year Intake              MCW                HDCW
# 4  ...         STYI  Start Year Intake              MCW                HDCW
# 5  ...         STYI  Start Year Intake              MCW                HDCW
# 6  ...         STYI  Start Year Intake              MCW                HDCW
# 7  ...         STYI  Start Year Intake              MCW                HDCW
# 8  ...         STYI  Start Year Intake              MCW                HDCW
# 9  ...         STYI  Start Year Intake              MCW                HDCW
#
#     DEGREETYPE LIABILITY_CATEGORY_CD_RECODE ORIG_LIABILITY_CATEGORY_CD_RECODE  \
# 0  Full Degree                           OF                                OF
# 1  Full Degree                           OF                                OF
# 2  Full Degree                           OF                                OF
# 3  Full Degree                           OF                                OF
# 4  Full Degree                           OF                                OF
# 5  Full Degree                           OF                                OF
# 6  Full Degree                           OF                                OF
# 7  Full Degree                           OF                                OF
# 8  Full Degree                           OF                                OF
# 9  Full Degree                           OF                                OF
#
#   OFFER_RELEASED_FG OFFER_OUTCOME_CD  OFFER_CONDITIONS
# 0                 Y             $ACC                 N
# 1                 Y             $ACC                 N
# 2                 Y             $ACC                 N
# 3                 Y             $ACC                 N
# 4                 Y             $ACC                 N
# 5                 Y             $ACC                 N
# 6                 Y             $ACC                 N
# 7                 Y             $ACC                 N
# 8                 Y             $ACC                 N
# 9                 Y             $ACC                 N
#
# [10 rows x 56 columns]

# %%
for i in range(len(df1)):
    id=df1.loc[i,'CASE_ID']
    status = df1.loc[i,"WRKFLW_TSK_MAP_GROUPED"]

# %%
ids = list(set(df1['CASE_ID'].values.tolist()))
ids
# Out:
# ['1172679|570743|869833',
#  '1079339|441319|682219',
#  '1031015|491641|755284',
#  '1058832|412318|639230',
#  '1115080|486030|746213',
#  '1035431|379192|590768',
#  '1070202|428739|664230',
#  '1103464|474796|728513',
#  '1146859|527552|807905',
#  '1128730|502322|771022',
#  '1041311|386435|601809',
#  '1003045|377363|588069',
#  '1107794|476586|731148',
#  '1126549|499378|766775',
#  '973212|295518|468360',
#  '1050212|397894|618995',
#  '1141086|519144|796076',
#  '1058293|411533|638081',
#  '1058870|412378|639304',
#  '571904|535714|819961',
#  '1183651|579635|880632',
#  '1055334|407345|631773',
#  '940839|560043|856793',
#  '1019923|525697|805597',
#  '1176842|570341|869262',
#  '935853|376312|586524',
#  '1102471|470654|722591',
#  '1056222|408664|633809',
#  '1150263|533103|815708',
#  '1163500|552931|845867',
#  '1035249|380457|600472',
#  '825846|382378|595573',
#  '1089401|453586|697002',
#  '962661|463369|711762',
#  '1162711|551723|844086',
#  '800907|397675|618710',
#  '1049546|397125|617916',
#  '1130086|504188|773783',
#  '1042012|387348|603149',
#  '1141397|545100|834533',
#  '1057960|416774|646125',
#  '1020437|359663|562888',
#  '1154227|539002|824855',
#  '1140162|523351|802245',
#  '1061095|415801|644553',
#  '1138282|515146|790009',
#  '1048053|570013|868840',
#  '1035315|379017|590497',
#  '1063851|475879|730042',
#  '779846|386297|601607',
#  '1096837|463658|712218',
#  '1125452|499335|766700',
#  '650819|349947|546064',
#  '1064294|420109|651063',
#  '904822|521036|798929',
#  '1087452|450685|692725',
#  '1028572|370265|577729',
#  '800226|366510|571873',
#  '1046563|393237|612123',
#  '1035863|379747|591607',
#  '965927|350025|546181',
#  '975590|538218|823753',
#  '1165812|556507|851046',
#  '1070993|429745|665721',
#  '1145882|525407|805158',
#  '1051625|400820|622934',
#  '1151950|554275|847784',
#  '1040203|385048|622542',
#  '1177840|571551|870942',
#  '1070219|428746|664237',
#  '1043577|389352|606313',
#  '940504|559382|855868',
#  '1007148|343419|536448',
#  '1185463|582025|883884',
#  '1043577|389352|606314',
#  '1137377|513793|788071',
#  '1025413|366670|572157',
#  '1052547|403066|625589',
#  '1160337|548318|839301',
#  '1022774|362590|565273',
#  '1093603|459342|705513',
#  '1169692|561546|858775',
#  '1073590|433268|670919',
#  '755008|316359|500822',
#  '942874|365098|569346',
#  '1061037|415762|644501',
#  '1060643|414977|643268',
#  '1165430|556024|850346',
#  '945608|396750|617361',
#  '1159932|547734|838445',
#  '1039854|384625|599033',
#  '1063001|418345|648434',
#  '1073238|432861|670234',
#  '1158296|545430|835107',
#  '779731|377874|588879',
#  '1042581|388072|604275',
#  '963171|276606|440328',
#  '1092032|457200|702151',
#  '1042581|388072|604276',
#  '692953|384693|599130',
#  '1095930|464146|712979',
#  '1026314|367267|573070',
#  '1047338|394173|613474',
#  '1079388|517437|793530',
#  '1060314|414471|642420',
#  '1162242|551068|843151',
#  '1125249|516133|791512',
#  '1128447|501954|770464',
#  '1071609|430746|667108',
#  '1034032|377346|588047',
#  '946750|419313|649888',
#  '1131627|559074|855415',
#  '1160692|549878|841412',
#  '1038598|383047|596567',
#  '1183928|579994|881205',
#  '1153219|561945|859423',
#  '1156740|543070|831064',
#  '1179743|574017|874264',
#  '1176765|570257|869145',
#  '1112278|485227|744774',
#  '1079012|440941|799897',
#  '1164379|554282|847792',
#  '1110145|478946|734725',
#  '1020121|467607|718299',
#  '1145936|529109|810280',
#  '1168358|559836|856536',
#  '1138264|515107|789952',
#  '904826|505101|775103',
#  '800228|391370|609335',
#  '1018554|438490|677893',
#  '879280|397304|618171',
#  '859860|561097|858210',
#  '1031713|374305|583681',
#  '1063118|418525|648710',
#  '1059323|413058|640330',
#  '1151178|534458|817955',
#  '1183934|580007|881222',
#  '1116167|556918|851905',
#  '1048638|395890|616091',
#  '1020990|362130|564569',
#  '936774|480069|736337',
#  ...]

# %%
S1S1 = pd.DataFrame()
S1S2 = pd.DataFrame()
S1S3 = pd.DataFrame()
S1S4 = pd.DataFrame()
S1S5 = pd.DataFrame()

#traverse each id
for id in ids:
    flag = True
    id_df = df1[df1['CASE_ID'] == id].loc[::-1].reset_index(drop = True)
    #id_df= id_df.iloc[::-1]
    sub_index,sendForAssessment_index,assessmentOutcomeSorNotS_index,releaseOffer_index,acceptOrDefer_index = -1,-1,-1,-1,-1
    #.loc[::-1].reset_index(drop = True) Reverse row order and reset index which let the first status stay at the first row:
    for index, row in id_df.iterrows():
        #record the index of first 'Submit' status per person
        if row['WRKFLW_TSK_MAP_GROUPED'] == 'Submit'and sub_index == -1:
            sub_index = index
        #record the index of first 'Send for Assessment' status per person
        elif row['WRKFLW_TSK_MAP_GROUPED'] == 'Send for Assessment'and sendForAssessment_index == -1:
            sendForAssessment_index = index
        #record the index of first 'Assessment Outcome' status per person
        elif (row['WRKFLW_TSK_MAP_GROUPED'] == 'Assessment Outcome - Successful'and assessmentOutcomeSorNotS_index == -1) \
                or (row['WRKFLW_TSK_MAP_GROUPED'] == 'Assessment Outcome - Not Successful'and assessmentOutcomeSorNotS_index == -1):
            assessmentOutcomeSorNotS_index = index
        #record the index of first 'Release Offer' status per person
        elif row['WRKFLW_TSK_MAP_GROUPED'] == 'Release Offer' and releaseOffer_index == -1:
            releaseOffer_index = index
        #record the index of first 'Accept/Defer' status per person
        elif (row['WRKFLW_TSK_MAP_GROUPED'] == 'Accept' and acceptOrDefer_index == -1) or\
                (row['WRKFLW_TSK_MAP_GROUPED'] == 'Defer' and acceptOrDefer_index == -1):
            acceptOrDefer_index = index
    #save the person status between submit and sendforassessment into S1
    if sub_index != -1 and sendForAssessment_index != -1:
        df_seg1 = id_df[sub_index:sendForAssessment_index+1]
        S1S1 = pd.concat([S1S1,df_seg1])
        flag = False
    #save the person status from submit and before sendforassessment into S1
    elif sub_index != -1 and sendForAssessment_index == -1 and assessmentOutcomeSorNotS_index == -1\
        and releaseOffer_index == -1 and acceptOrDefer_index == -1:
        df_seg1 = id_df
        S1S1 = pd.concat([S1S1,df_seg1])
        flag = False
    #save the person status between sendforassessment and assessmentOutcome into S2
    if sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index != -1:
        df_seg2=id_df[sendForAssessment_index:assessmentOutcomeSorNotS_index+1]
        S1S2 = pd.concat([S1S2,df_seg2])
        flag = False
    #save the person status from sendforassessment and before assessmentOutcome into S2
    elif sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index == -1\
        and releaseOffer_index == -1 and acceptOrDefer_index == -1:
        df_seg2=id_df[sendForAssessment_index:]
        S1S2 = pd.concat([S1S2,df_seg2])
        flag = False
    #save the person status between assessmentOutcome and relaseoffer into S3
    if assessmentOutcomeSorNotS_index!=-1 and releaseOffer_index != -1:
        df_seg3=id_df[assessmentOutcomeSorNotS_index:releaseOffer_index +1]
        S1S3 = pd.concat([S1S3,df_seg3])
        flag = False
    #save the person status from assessmentOutcome and before relaseoffer into S3
    elif assessmentOutcomeSorNotS_index != -1 and releaseOffer_index == -1\
            and acceptOrDefer_index == -1:
        df_seg3=id_df[assessmentOutcomeSorNotS_index:]
        S1S3 = pd.concat([S1S3,df_seg3])
        flag = False
    #save the person status between relaseoffer and acceptordefer into S4
    if releaseOffer_index!=-1 and acceptOrDefer_index != -1:
        df_seg4=id_df[releaseOffer_index:acceptOrDefer_index+1]
        S1S4 = pd.concat([S1S4,df_seg4])
        flag = False
    #save the person status from relaseoffer and before acceptordefer into S4
    elif releaseOffer_index != -1 and acceptOrDefer_index == -1:
        df_seg4=id_df[releaseOffer_index:]
        S1S4 = pd.concat([S1S4,df_seg4])
        flag = False
    #save the person who didn't belong to before four segements
    if flag == True:
        S1S5 = pd.concat([S1S5,id_df])

# %%
#segment1
S1S1.head(n=10)
S1S1.to_csv("segment1_workflowS1.csv",index=False)

# %%
#segmnent2
S1S2.head(n=10)
S1S2.to_csv("segment1_workflowS2.csv",index=False)

# %%
#segment3
S1S3.head(n=10)
S1S3.to_csv("segment1_workflowS3.csv",index=False)

# %%
#segment4
S1S4.head(n=10)
S1S4.to_csv("segment1_workflowS4.csv",index=False)

# %%
#appliers didn't count into those 4 segments
S1S5.head(n=10)
S1S5.to_csv("segment1_workflowS5.csv",index=False)
