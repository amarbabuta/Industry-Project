# %%
import pandas as pd
import csv
import numpy as np
from datetime import datetime

# %%
df3 = pd.read_csv("/Users/asteriag/Desktop/DATASCIENCEPROJECT_WORKFLOW/Workflow/workflow_segment3.csv")

# %%
df3.head(n=10)
# Out:
#                CASE_ID                       WRKFLW_TSK_MAP_GROUPED  \
# 0  502030|95557|149167              Assessment Decision - Qualified
# 1  502030|95557|149167              Assessment Decision - Qualified
# 2  502030|95557|149167                            Manage Acceptance
# 3  502030|95557|149167                                       Accept
# 4  502030|95557|149167                                Release Offer
# 5  502030|95557|149167                                 Create Offer
# 6  502030|95557|149167              Assessment Outcome - Successful
# 7  502030|95557|149167                         OC - Created - Other
# 8  502030|95557|149167  Acacdemic - Assessment Decision - Qualified
# 9  502030|95557|149167              Assessment Decision - Qualified
#
#                         WRKFLW_TSK_MAP_DETAILED     PATH_CRDATETIME  \
# 0               Assessment Decision - Qualified  28/7/2016 16:10:40
# 1               Assessment Decision - Qualified  28/7/2016 16:01:11
# 2                             Manage Acceptance  24/5/2016 13:26:06
# 3                                        Accept  24/5/2016 13:26:06
# 4                                 Release Offer  26/4/2016 16:27:24
# 5                                  Create Offer  26/4/2016 16:06:40
# 6               Assessment Outcome - Successful  26/4/2016 16:06:32
# 7  OC - Created - Evidence of course completion  26/4/2016 16:04:02
# 8   Acacdemic - Assessment Decision - Qualified  22/4/2016 15:55:48
# 9               Assessment Decision - Qualified  15/4/2016 15:04:09
#
#   ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER LATEST_STATUS  \
# 0   THOMPSONN                Faculty             1             Y
# 1   THOMPSONN                Faculty             2             N
# 2      502030                    NaN             3             N
# 3    CGRAVIER                Faculty             4             N
# 4    CGRAVIER                Faculty             5             N
# 5    CGRAVIER                Faculty             6             N
# 6    CGRAVIER                Faculty             7             N
# 7    CGRAVIER                Faculty             8             N
# 8       KARUS               Academic             9             N
# 9     BRENTJ1                Faculty            10             N
#
#           WRKFLW_PROCESS                             QUERY_PART  ...  \
# 0  2. Perform Assessment           Part 4 - Assessment Decision  ...
# 1  2. Perform Assessment           Part 4 - Assessment Decision  ...
# 2          4. Post offer  Part 2 - Application Line ID Workflow  ...
# 3          4. Post offer  Part 2 - Application Line ID Workflow  ...
# 4        3b. Offer stage  Part 2 - Application Line ID Workflow  ...
# 5        3b. Offer stage  Part 2 - Application Line ID Workflow  ...
# 6  2. Perform Assessment            Part 3 - Assessment Outcome  ...
# 7   1. App to Assessment            Part 5 - Requirement Create  ...
# 8  2. Perform Assessment           Part 4 - Assessment Decision  ...
# 9  2. Perform Assessment           Part 4 - Assessment Decision  ...
#
#   ORIG_SPRD_CD       ORIG_SPRD_NM  SPK_CAT_TYPE_CD  BROAD_COURSE_LEVEL  \
# 0         STYI  Start Year Intake              MCW                HDCW
# 1         STYI  Start Year Intake              MCW                HDCW
# 2         STYI  Start Year Intake              MCW                HDCW
# 3         STYI  Start Year Intake              MCW                HDCW
# 4         STYI  Start Year Intake              MCW                HDCW
# 5         STYI  Start Year Intake              MCW                HDCW
# 6         STYI  Start Year Intake              MCW                HDCW
# 7         STYI  Start Year Intake              MCW                HDCW
# 8         STYI  Start Year Intake              MCW                HDCW
# 9         STYI  Start Year Intake              MCW                HDCW
#
#     DEGREETYPE LIABILITY_CATEGORY_CD_RECODE ORIG_LIABILITY_CATEGORY_CD_RECODE  \
# 0  Full Degree                           AF                                AS
# 1  Full Degree                           AF                                AS
# 2  Full Degree                           AF                                AS
# 3  Full Degree                           AF                                AS
# 4  Full Degree                           AF                                AS
# 5  Full Degree                           AF                                AS
# 6  Full Degree                           AF                                AS
# 7  Full Degree                           AF                                AS
# 8  Full Degree                           AF                                AS
# 9  Full Degree                           AF                                AS
#
#   OFFER_RELEASED_FG OFFER_OUTCOME_CD  OFFER_CONDITIONS
# 0                 Y             $ACC                 N
# 1                 Y             $ACC                 N
# 2                 Y             $ACC                 N
# 3                 Y             $ACC                 N
# 4                 Y             $ACC                 N
# 5                 Y             $ACC                 N
# 6                 Y             $ACC                 N
# 7                 Y             $ACC                 N
# 8                 Y             $ACC                 N
# 9                 Y             $ACC                 N
#
# [10 rows x 56 columns]

# %%
for i in range(len(df3)):
    id=df3.loc[i,'CASE_ID']
    status = df3.loc[i,"WRKFLW_TSK_MAP_GROUPED"]

# %%
ids = list(set(df3['CASE_ID'].values.tolist()))
ids
# Out:
# ['1161800|550469|842233',
#  '1145219|524914|804465',
#  '1121555|583498|885963',
#  '1022190|362029|564420',
#  '1158342|545497|835196',
#  '1097483|464341|713275',
#  '1077299|440564|681103',
#  '1077299|440564|681102',
#  '502030|95557|149167',
#  '860115|582167|884085',
#  '835603|395509|615479',
#  '1021374|367597|573577',
#  '1023596|363705|567084',
#  '1135836|561684|858976',
#  '833200|362700|565447',
#  '1045644|574424|874819',
#  '1150782|553964|847373',
#  '885532|508149|779756',
#  '1116512|486416|746788',
#  '1048849|396177|616539',
#  '1048849|396177|616538',
#  '1156691|542991|830966',
#  '1130311|558178|854096',
#  '1114833|484364|743307',
#  '1129836|503867|773292',
#  '1017482|356016|555094',
#  '1017482|356016|555093',
#  '1097690|464562|713616',
#  '1097690|464562|713617',
#  '1150782|553964|847372',
#  '1018151|356878|556384',
#  '904876|527155|807291',
#  '1142533|521081|798988',
#  '1034538|378000|589091',
#  '914734|522126|800455',
#  '914734|522126|800454',
#  '914734|522126|800456',
#  '1115769|485466|745172',
#  '1115769|485466|745171',
#  '927759|475045|728852',
#  '857028|429692|665643',
#  '1129248|506904|777794',
#  '1151482|549626|841020',
#  '1168534|560047|856798',
#  '1179677|573921|874117',
#  '1068696|426431|660784',
#  '1068696|426431|660782',
#  '614843|559663|856264',
#  '1098231|465254|714692',
#  '832919|404288|627219',
#  '1105117|473362|726430',
#  '1032525|375569|585384',
#  '960824|535900|820254',
#  '1158036|554158|847629',
#  '1097405|464257|713158',
#  '1097405|464257|713159',
#  '904907|499819|767433',
#  '1034656|378152|589286',
#  '1117605|488390|749984',
#  '1112194|481665|738909',
#  '1045755|501046|769108',
#  '1022348|362011|564389',
#  '702235|479390|735328',
#  '940176|243843|388437',
#  '266336|568045|866098',
#  '1058761|412208|639044',
#  '1090139|454580|698531',
#  '1128028|512080|785569',
#  '830884|476339|730796',
#  '1069286|427326|662193',
#  '1069286|427326|662192',
#  '835863|420477|651607',
#  '835863|420477|651606',
#  '1067449|424909|657898',
#  '1177989|571742|871247',
#  '935479|535381|819449',
#  '1101054|468718|719852',
#  '1076747|476620|731205',
#  '1105285|503490|772750',
#  '1076747|476620|731206',
#  '1102908|470757|722758',
#  '1063956|419530|650202',
#  '1047047|393821|612952',
#  '348110|431933|668864',
#  '1135397|511059|784010',
#  '722408|378330|589526',
#  '912174|506107|776645',
#  '1113797|483123|741280',
#  '735247|392945|611679',
#  '1029328|371595|579504',
#  '1040164|385001|599630',
#  '1068603|426591|661039',
#  '1062725|427270|662103',
#  '1167627|558813|855004',
#  '1125242|497408|763842',
#  '1034446|377904|588943',
#  '1077830|439346|679327',
#  '1150349|533218|815876',
#  '1108597|477482|732532',
#  '1156828|545180|834640',
#  '834579|497265|763633',
#  '910725|551401|843627',
#  '886776|417211|646765',
#  '1132345|507110|778104',
#  '1093159|500851|768798',
#  '1132164|554724|848466',
#  '958145|268178|427378',
#  '1068603|426591|661041',
#  '1075305|437160|675799',
#  '837735|422153|653783',
#  '1066003|422765|654738',
#  '641437|484958|744358',
#  '855738|481191|738122',
#  '389899|547897|838667',
#  '1132012|506654|777406',
#  '389899|547897|838666',
#  '1148396|529731|811229',
#  '266336|568045|866097',
#  '1045292|391510|609537',
#  '1071755|435422|673466',
#  '1153045|537241|822220',
#  '1153045|537241|822221',
#  '1138305|515182|790060',
#  '1153045|537241|822223',
#  '1156828|545180|834639',
#  '1025305|366531|571922',
#  '1144798|524117|803394',
#  '1133127|508191|779818',
#  '1038402|400002|648258',
#  '1033710|376995|587501',
#  '1033710|376995|587502',
#  '1163925|569849|868633',
#  '758712|388254|604631',
#  '913320|552081|844602',
#  '1063862|419463|673689',
#  '1116137|485965|746118',
#  '374924|439273|679201',
#  '1024187|364497|568368',
#  '1116137|485965|746117',
#  '757397|413413|640865',
#  '830762|432576|669850',
#  '1098958|466137|716092',
#  '762986|428095|663266',
#  '1070151|428788|664296',
#  '831996|418073|648010',
#  '913908|506412|777062',
#  '1045167|470581|722487',
#  '1128107|501518|769785',
#  '759903|350829|547396',
#  '1040982|386008|601183',
#  '1021829|361369|563371',
#  '1126335|510700|783523',
#  '1069136|427063|661781',
#  '1039537|384322|598550',
#  '1143409|522225|800591',
#  '1163445|552901|845823',
#  '1184026|580133|881397',
#  '758235|422186|653829',
#  '1057584|411091|637400',
#  '1129852|508725|780625',
#  '768023|340351|531837',
#  '1064461|420298|651352',
#  '636640|374250|583595',
#  '1037562|386109|601336',
#  '1076583|437721|676610',
#  '1152307|536120|820540',
#  '1034720|382304|595455']

# %%
S3S1 = pd.DataFrame()
S3S2 = pd.DataFrame()
S3S3 = pd.DataFrame()
S3S4 = pd.DataFrame()
S3S5 = pd.DataFrame()

#traverse each id
for id in ids:
    flag = True
    #.loc[::-1].reset_index(drop = True) Reverse row order and reset index which let the first status stay at the first row:
    id_df = df3[df3['CASE_ID'] == id].loc[::-1].reset_index(drop = True)
    #id_df= id_df.iloc[::-1]
    sub_index,sendForAssessment_index,assessmentOutcomeSorNotS_index,releaseOffer_index,acceptOrDefer_index = -1,-1,-1,-1,-1
    for index, row in id_df.iterrows():
        #record the index of first 'Submit' status per person
        if row['WRKFLW_TSK_MAP_GROUPED'] == 'Submit'and sub_index == -1:
            sub_index = index
        #record the index of first 'Send for Assessment' status per person
        elif row['WRKFLW_TSK_MAP_GROUPED'] == 'Send for Assessment'and sendForAssessment_index == -1:
            sendForAssessment_index = index
        #record the index of first 'Assessment Outcome' status per person
        elif (row['WRKFLW_TSK_MAP_GROUPED'] == 'Assessment Outcome - Successful'and assessmentOutcomeSorNotS_index == -1) \
                or (row['WRKFLW_TSK_MAP_GROUPED'] == 'Assessment Outcome - Not Successful'and assessmentOutcomeSorNotS_index == -1):
            assessmentOutcomeSorNotS_index = index
        #record the index of first 'Release Offer' status per person
        elif row['WRKFLW_TSK_MAP_GROUPED'] == 'Release Offer' and releaseOffer_index == -1:
            releaseOffer_index = index
        #record the index of first 'Accept/Defer' status per person
        elif (row['WRKFLW_TSK_MAP_GROUPED'] == 'Accept' and acceptOrDefer_index == -1) or\
                (row['WRKFLW_TSK_MAP_GROUPED'] == 'Defer' and acceptOrDefer_index == -1):
            acceptOrDefer_index = index
    #save the person status between submit and sendforassessment into S1
    if sub_index != -1 and sendForAssessment_index != -1:
        df_seg1 = id_df[sub_index:sendForAssessment_index+1]
        S3S1 = pd.concat([S3S1,df_seg1])
        flag = False
    #save the person status from submit and before sendforassessment into S1
    elif sub_index != -1 and sendForAssessment_index == -1 and assessmentOutcomeSorNotS_index == -1\
        and releaseOffer_index == -1 and acceptOrDefer_index == -1:
        df_seg1 = id_df
        S3S1 = pd.concat([S3S1,df_seg1])
        flag = False
    #save the person status between sendforassessment and assessmentOutcome into S2
    if sub_index != -1 and sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index != -1:
        df_seg2=id_df[sendForAssessment_index:assessmentOutcomeSorNotS_index+1]
        S3S2 = pd.concat([S3S2,df_seg2])
        flag = False
    #save the person status from sendforassessment and before assessmentOutcome into S2
    elif sub_index != -1 and sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index == -1\
        and releaseOffer_index == -1 and acceptOrDefer_index == -1:
        df_seg2=id_df[sendForAssessment_index:]
        S3S2 = pd.concat([S3S2,df_seg2])
        flag = False
    #save the person status between assessmentOutcome and relaseoffer into S3
    if sub_index != -1 and sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index!=-1 and releaseOffer_index != -1:
        df_seg3=id_df[assessmentOutcomeSorNotS_index:releaseOffer_index +1]
        S3S3 = pd.concat([S3S3,df_seg3])
        flag = False
    #save the person status from assessmentOutcome and before relaseoffer into S3
    elif sub_index != -1 and sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index != -1 and releaseOffer_index == -1\
            and acceptOrDefer_index == -1:
        df_seg3=id_df[assessmentOutcomeSorNotS_index:]
        S3S3 = pd.concat([S3S3,df_seg3])
        flag = False
    #save the person status between relaseoffer and acceptordefer into S4
    if sub_index != -1 and sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index != -1 and releaseOffer_index!=-1 and acceptOrDefer_index != -1:
        df_seg4=id_df[releaseOffer_index:acceptOrDefer_index+1]
        S3S4 = pd.concat([S3S4,df_seg4])
        flag = False
    #save the person status from relaseoffer and before acceptordefer into S4
    elif sub_index != -1 and sendForAssessment_index != -1 and assessmentOutcomeSorNotS_index != -1 and releaseOffer_index != -1 and acceptOrDefer_index == -1:
        df_seg4=id_df[releaseOffer_index:]
        S3S4 = pd.concat([S3S4,df_seg4])
        flag = False
    #save the person who didn't belong to before four segements
    if flag == True:
        S3S5 = pd.concat([S3S5,id_df])

# %%
#segment1
S3S1.head(n=10)
S3S1.to_csv("segment3_workflowS1.csv",index=False)

# %%
#segmnent2
S3S2.head(n=10)
S3S2.to_csv("segment3_workflowS2.csv",index=False)

# %%
#segment3
S3S3.head(n=10)
S3S3.to_csv("segment3_workflowS3.csv",index=False)

# %%
#segment4
S3S4.head(n=10)
S3S4.to_csv("segment3_workflowS4.csv",index=False)

# %%
#appliers didn't count into those 4 segments
S3S5.head(n=10)
S3S5.to_csv("segment3_workflowS5.csv",index=False)
