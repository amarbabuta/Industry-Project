# %%
import pandas as pd

# %%
df3_WS1T = pd.read_csv("engineering_AS_segment2_workflowS4_has_duration.csv",engine='python')

# %%
df3_WS1T.head(n=1)
# Out:
#                 CASE_ID WRKFLW_TSK_MAP_GROUPED WRKFLW_TSK_MAP_DETAILED  \
# 0  521428|372279|580506          Release Offer           Release Offer
#
#      PATH_CRDATETIME ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER  \
# 0  2/8/2018 12:51:10  CHRISTINAA                Faculty            11
#
#   LATEST_STATUS   WRKFLW_PROCESS                             QUERY_PART  ...  \
# 0             N  3b. Offer stage  Part 2 - Application Line ID Workflow  ...
#
#   SPK_CAT_TYPE_CD  BROAD_COURSE_LEVEL   DEGREETYPE  \
# 0             MCW                HDCW  Full Degree
#
#    LIABILITY_CATEGORY_CD_RECODE  ORIG_LIABILITY_CATEGORY_CD_RECODE  \
# 0                            AS                                 AS
#
#   OFFER_RELEASED_FG OFFER_OUTCOME_CD OFFER_CONDITIONS  \
# 0                 Y             $ACC                Y
#
#                             time_used_str  time_used_second
# 0  111 days 3 hours 46 minutes 28 seconds         9603988.0
#
# [1 rows x 58 columns]

# %%
#store unique WRKFLW_TSK_MAP_DETAILED
WRKFLW_TSK_MAP_DETAILED_list = df3_WS1T['WRKFLW_TSK_MAP_DETAILED'].tolist()
unique_WRKFLW_TSK_MAP_DETAILED_list = set(WRKFLW_TSK_MAP_DETAILED_list)
len(unique_WRKFLW_TSK_MAP_DETAILED_list)
unique_WRKFLW_TSK_MAP_DETAILED_list
# Out:
# {'AR - Reviewed - Official syllabus or subject descriptions (in English)',
#  'AR - Satisfied - Further information (1)',
#  'Accept',
#  'Assessment Decision - No Decision',
#  'Assessment Decision - Qualified',
#  'Defer',
#  'Manage Acceptance',
#  'OC - Requested - English language requirements',
#  'OC - Satisfied - Evidence of course completion',
#  'Release Offer'}

# %%
#store unique CASE_ID
ID_list = df3_WS1T['CASE_ID'].tolist()
unique_ID_list = set(ID_list)
len(unique_ID_list)
# Out:
# 23

# %%
#create dataframe columns->unique_WRKFLW_TSK_MAP_DETAILED row->unique_ID
df = pd.DataFrame(columns = unique_WRKFLW_TSK_MAP_DETAILED_list, index = unique_ID_list )
df
# Out:
#                       Defer Manage Acceptance  \
# 1045755|441165|681992   NaN               NaN
# 841583|393054|611843    NaN               NaN
# 1102417|470238|722008   NaN               NaN
# 556092|418746|649064    NaN               NaN
# 1156222|542251|829832   NaN               NaN
# 831209|419422|650060    NaN               NaN
# 990545|323544|511318    NaN               NaN
# 834063|417186|646721    NaN               NaN
# 759141|363501|566737    NaN               NaN
# 1104975|473209|726228   NaN               NaN
# 1071012|541292|828351   NaN               NaN
# 1144647|523920|803104   NaN               NaN
# 1089677|479341|735255   NaN               NaN
# 1079286|506989|777934   NaN               NaN
# 339918|468523|719583    NaN               NaN
# 841551|415834|644607    NaN               NaN
# 831339|546066|836047    NaN               NaN
# 1163793|555726|849921   NaN               NaN
# 883043|411872|667486    NaN               NaN
# 1158188|545234|834728   NaN               NaN
# 836435|552668|845455    NaN               NaN
# 521428|372279|580506    NaN               NaN
# 1068414|425956|660100   NaN               NaN
#
#                       OC - Requested - English language requirements  \
# 1045755|441165|681992                                            NaN
# 841583|393054|611843                                             NaN
# 1102417|470238|722008                                            NaN
# 556092|418746|649064                                             NaN
# 1156222|542251|829832                                            NaN
# 831209|419422|650060                                             NaN
# 990545|323544|511318                                             NaN
# 834063|417186|646721                                             NaN
# 759141|363501|566737                                             NaN
# 1104975|473209|726228                                            NaN
# 1071012|541292|828351                                            NaN
# 1144647|523920|803104                                            NaN
# 1089677|479341|735255                                            NaN
# 1079286|506989|777934                                            NaN
# 339918|468523|719583                                             NaN
# 841551|415834|644607                                             NaN
# 831339|546066|836047                                             NaN
# 1163793|555726|849921                                            NaN
# 883043|411872|667486                                             NaN
# 1158188|545234|834728                                            NaN
# 836435|552668|845455                                             NaN
# 521428|372279|580506                                             NaN
# 1068414|425956|660100                                            NaN
#
#                       AR - Reviewed - Official syllabus or subject descriptions (in English)  \
# 1045755|441165|681992                                                NaN
# 841583|393054|611843                                                 NaN
# 1102417|470238|722008                                                NaN
# 556092|418746|649064                                                 NaN
# 1156222|542251|829832                                                NaN
# 831209|419422|650060                                                 NaN
# 990545|323544|511318                                                 NaN
# 834063|417186|646721                                                 NaN
# 759141|363501|566737                                                 NaN
# 1104975|473209|726228                                                NaN
# 1071012|541292|828351                                                NaN
# 1144647|523920|803104                                                NaN
# 1089677|479341|735255                                                NaN
# 1079286|506989|777934                                                NaN
# 339918|468523|719583                                                 NaN
# 841551|415834|644607                                                 NaN
# 831339|546066|836047                                                 NaN
# 1163793|555726|849921                                                NaN
# 883043|411872|667486                                                 NaN
# 1158188|545234|834728                                                NaN
# 836435|552668|845455                                                 NaN
# 521428|372279|580506                                                 NaN
# 1068414|425956|660100                                                NaN
#
#                       Assessment Decision - Qualified  \
# 1045755|441165|681992                             NaN
# 841583|393054|611843                              NaN
# 1102417|470238|722008                             NaN
# 556092|418746|649064                              NaN
# 1156222|542251|829832                             NaN
# 831209|419422|650060                              NaN
# 990545|323544|511318                              NaN
# 834063|417186|646721                              NaN
# 759141|363501|566737                              NaN
# 1104975|473209|726228                             NaN
# 1071012|541292|828351                             NaN
# 1144647|523920|803104                             NaN
# 1089677|479341|735255                             NaN
# 1079286|506989|777934                             NaN
# 339918|468523|719583                              NaN
# 841551|415834|644607                              NaN
# 831339|546066|836047                              NaN
# 1163793|555726|849921                             NaN
# 883043|411872|667486                              NaN
# 1158188|545234|834728                             NaN
# 836435|552668|845455                              NaN
# 521428|372279|580506                              NaN
# 1068414|425956|660100                             NaN
#
#                       Assessment Decision - No Decision Release Offer Accept  \
# 1045755|441165|681992                               NaN           NaN    NaN
# 841583|393054|611843                                NaN           NaN    NaN
# 1102417|470238|722008                               NaN           NaN    NaN
# 556092|418746|649064                                NaN           NaN    NaN
# 1156222|542251|829832                               NaN           NaN    NaN
# 831209|419422|650060                                NaN           NaN    NaN
# 990545|323544|511318                                NaN           NaN    NaN
# 834063|417186|646721                                NaN           NaN    NaN
# 759141|363501|566737                                NaN           NaN    NaN
# 1104975|473209|726228                               NaN           NaN    NaN
# 1071012|541292|828351                               NaN           NaN    NaN
# 1144647|523920|803104                               NaN           NaN    NaN
# 1089677|479341|735255                               NaN           NaN    NaN
# 1079286|506989|777934                               NaN           NaN    NaN
# 339918|468523|719583                                NaN           NaN    NaN
# 841551|415834|644607                                NaN           NaN    NaN
# 831339|546066|836047                                NaN           NaN    NaN
# 1163793|555726|849921                               NaN           NaN    NaN
# 883043|411872|667486                                NaN           NaN    NaN
# 1158188|545234|834728                               NaN           NaN    NaN
# 836435|552668|845455                                NaN           NaN    NaN
# 521428|372279|580506                                NaN           NaN    NaN
# 1068414|425956|660100                               NaN           NaN    NaN
#
#                       AR - Satisfied - Further information (1)  \
# 1045755|441165|681992                                      NaN
# 841583|393054|611843                                       NaN
# 1102417|470238|722008                                      NaN
# 556092|418746|649064                                       NaN
# 1156222|542251|829832                                      NaN
# 831209|419422|650060                                       NaN
# 990545|323544|511318                                       NaN
# 834063|417186|646721                                       NaN
# 759141|363501|566737                                       NaN
# 1104975|473209|726228                                      NaN
# 1071012|541292|828351                                      NaN
# 1144647|523920|803104                                      NaN
# 1089677|479341|735255                                      NaN
# 1079286|506989|777934                                      NaN
# 339918|468523|719583                                       NaN
# 841551|415834|644607                                       NaN
# 831339|546066|836047                                       NaN
# 1163793|555726|849921                                      NaN
# 883043|411872|667486                                       NaN
# 1158188|545234|834728                                      NaN
# 836435|552668|845455                                       NaN
# 521428|372279|580506                                       NaN
# 1068414|425956|660100                                      NaN
#
#                       OC - Satisfied - Evidence of course completion
# 1045755|441165|681992                                            NaN
# 841583|393054|611843                                             NaN
# 1102417|470238|722008                                            NaN
# 556092|418746|649064                                             NaN
# 1156222|542251|829832                                            NaN
# 831209|419422|650060                                             NaN
# 990545|323544|511318                                             NaN
# 834063|417186|646721                                             NaN
# 759141|363501|566737                                             NaN
# 1104975|473209|726228                                            NaN
# 1071012|541292|828351                                            NaN
# 1144647|523920|803104                                            NaN
# 1089677|479341|735255                                            NaN
# 1079286|506989|777934                                            NaN
# 339918|468523|719583                                             NaN
# 841551|415834|644607                                             NaN
# 831339|546066|836047                                             NaN
# 1163793|555726|849921                                            NaN
# 883043|411872|667486                                             NaN
# 1158188|545234|834728                                            NaN
# 836435|552668|845455                                             NaN
# 521428|372279|580506                                             NaN
# 1068414|425956|660100                                            NaN

# %%
#sotre id as key and workflow detail of the id as value into dictionary
from collections import defaultdict
ID_WRKFLW_dict = defaultdict(list)
for i, j in zip(df3_WS1T.CASE_ID,df3_WS1T.WRKFLW_TSK_MAP_DETAILED):
    ID_WRKFLW_dict[i].append(j)
len(ID_WRKFLW_dict)
# Out:
# 23

# %%
#change the value
for key in ID_WRKFLW_dict.keys():
    for process in ID_WRKFLW_dict[key]:
            df.loc[key, process] = 1
zero_one_table = df.fillna(0)
zero_one_table
# Out:
#                        Defer  Manage Acceptance  \
# 1045755|441165|681992      1                  0
# 841583|393054|611843       0                  0
# 1102417|470238|722008      0                  0
# 556092|418746|649064       0                  0
# 1156222|542251|829832      0                  1
# 831209|419422|650060       0                  0
# 990545|323544|511318       0                  0
# 834063|417186|646721       0                  0
# 759141|363501|566737       0                  0
# 1104975|473209|726228      0                  0
# 1071012|541292|828351      0                  1
# 1144647|523920|803104      0                  0
# 1089677|479341|735255      0                  0
# 1079286|506989|777934      0                  1
# 1079286|506989|777934                                  1              1
# 339918|468523|719583                                   0              1
# 841551|415834|644607                                   0              1
# 831339|546066|836047                                   0              1
# 1163793|555726|849921                                  0              1
# 883043|411872|667486                                   0              1
# 1158188|545234|834728                                  0              1
# 836435|552668|845455                                   0              1
# 521428|372279|580506                                   0              1
# 1068414|425956|660100                                  0              1
#
#                        Accept  AR - Satisfied - Further information (1)  \
# 1045755|441165|681992       0                                         0
# 841583|393054|611843        1                                         0
# 1102417|470238|722008       1                                         0
# 556092|418746|649064        1                                         0
# 1156222|542251|829832       1                                         0
# 831209|419422|650060        1                                         0
# 990545|323544|511318        1                                         0
# 834063|417186|646721        1                                         0
# 759141|363501|566737        1                                         0
# 1104975|473209|726228       1                                         0
# 1071012|541292|828351       1                                         0
# 1144647|523920|803104       0                                         0
# 1089677|479341|735255       0                                         0
# 1079286|506989|777934       1                                         0
# 339918|468523|719583        1                                         0
# 841551|415834|644607        0                                         0
# 831339|546066|836047        1                                         0
# 1163793|555726|849921       0                                         0
# 883043|411872|667486        1                                         0
# 1158188|545234|834728       0                                         0
# 836435|552668|845455        0                                         0
# 521428|372279|580506        1                                         0
# 1068414|425956|660100       0                                         1
#
#                        OC - Satisfied - Evidence of course completion
# 1045755|441165|681992                                               0
# 841583|393054|611843                                                0
# 1102417|470238|722008                                               0
# 556092|418746|649064                                                0
# 1156222|542251|829832                                               0
# 831209|419422|650060                                                0
# 990545|323544|511318                                                0
# 834063|417186|646721                                                0
# 759141|363501|566737                                                1
# 1104975|473209|726228                                               0
# 1071012|541292|828351                                               0
# 1144647|523920|803104                                               0
# 1089677|479341|735255                                               0
# 1079286|506989|777934                                               0
# 339918|468523|719583                                                0
# 841551|415834|644607                                                0
# 831339|546066|836047                                                0
# 1163793|555726|849921                                               0
# 883043|411872|667486                                                0
# 1158188|545234|834728                                               0
# 836435|552668|845455                                                0
# 521428|372279|580506                                                1
# 1068414|425956|660100                                               0

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

features= list(unique_WRKFLW_TSK_MAP_DETAILED_list)
print(len(features))
features.remove('Accept')
features.remove('Defer')
print(len(features))

X=zero_one_table[features]
y=zero_one_table ['Accept'] # Labels
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # 70% training and 30% test
# Out:
# 10
# 8

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 8,
                             random_state = 0)
clf.fit(X_train, y_train)
clf_pred = clf.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, clf_pred))
print(classification_report(y_test, clf_pred))
# Out:
# [[0 2]
#  [0 4]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.67      1.00      0.80         4
#
#     accuracy                           0.67         6
#    macro avg       0.33      0.50      0.40         6
# weighted avg       0.44      0.67      0.53         6
# /Users/ab0707/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# DOT data
from IPython.display import Image
from sklearn import tree
import pydotplus
fn=features
cn=['0', '1']
# Create DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=fn,
                                class_names=cn,filled = True)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
# Show graph
Image(graph.create_png())

# %%
# Create PNG
graph.write_png("engineering_AS_segment2_workflowS4_decisiontree.png")
# Out:
# True

# %%
zero_one_table['Accept'].value_counts()
# Out:
# 1    15
# 0     8
# Name: Accept, dtype: int64

# %%
from sklearn.utils import resample

# Separate majority and minority classes
zero_one_table_majority = df[zero_one_table['Accept']==1]
zero_one_table_minority = df[zero_one_table['Accept']==0]

# Upsample minority class
df_majority_downsampled = resample(zero_one_table_majority,
                                 replace=False,     # sample with replacement
                                 n_samples=8,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_downsampled = pd.concat([zero_one_table_minority, df_majority_downsampled])

# Display new class counts
df_downsampled = df_downsampled.fillna(0)
df_downsampled['Accept'].value_counts()
# Out:
# 1    8
# 0    8
# Name: Accept, dtype: int64

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X=df_downsampled[features]
y=df_downsampled ['Accept'] # Labels
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # 70% training and 30% test

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 8,
                             random_state = 0)
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.75

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[2 0]
#  [1 1]]
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4

# %%
# DOT data
from IPython.display import Image
from sklearn import tree
import pydotplus
fn=features
cn=['0', '1']
# Create DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=fn,
                                class_names=cn,filled = True)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
# Show graph
Image(graph.create_png())

# %%
# Create PNG
graph.write_png("engineering_AS_segment2_workflowS4_decisiontree_downsampled.png")
# Out:
# True
