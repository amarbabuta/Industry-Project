# %%
import pandas as pd

# %%
df3_WS1T = pd.read_csv("/Users/asteriag/Desktop/DATASCIENCEPROJECT_WORKFLOW/TimeStamp_Engineering/engineering_OF_segment1_workflowS1_has_duration.csv",engine='python')

# %%
df3_WS1T.head(n=1)
# Out:
#                 CASE_ID WRKFLW_TSK_MAP_GROUPED WRKFLW_TSK_MAP_DETAILED  \
# 0  817772|403654|626458                 Submit                  Submit
#
#       PATH_CRDATETIME ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER  \
# 0  13/9/2018 15:40:36       GUEST                Student            15
#
#   LATEST_STATUS        WRKFLW_PROCESS                        QUERY_PART  ...  \
# 0             N  1. App to Assessment  Part 1 - Application ID Workflow  ...
#
#   SPK_CAT_TYPE_CD  BROAD_COURSE_LEVEL   DEGREETYPE  \
# 0             MCW                HDCW  Full Degree
#
#    LIABILITY_CATEGORY_CD_RECODE  ORIG_LIABILITY_CATEGORY_CD_RECODE  \
# 0                            OF                                 OF
#
#   OFFER_RELEASED_FG OFFER_OUTCOME_CD OFFER_CONDITIONS  \
# 0                 Y              NaN                Y
#
#                             time_used_str  time_used_second
# 0  24 days 20 hours 54 minutes 46 seconds         2148886.0
#
# [1 rows x 58 columns]

# %%
#store unique WRKFLW_TSK_MAP_DETAILED
WRKFLW_TSK_MAP_DETAILED_list = df3_WS1T['WRKFLW_TSK_MAP_DETAILED'].tolist()
unique_WRKFLW_TSK_MAP_DETAILED_list = set(WRKFLW_TSK_MAP_DETAILED_list)
len(unique_WRKFLW_TSK_MAP_DETAILED_list)
unique_WRKFLW_TSK_MAP_DETAILED_list
# Out:
# {'AR - Awaiting External Response - Appointment of authorised representative',
#  'AR - Awaiting External Response - Further information (1)',
#  'AR - Created - Academic referee reports (Staff only)',
#  'AR - Created - Academic results for prior tertiary studies',
#  'AR - Created - Academic transcript Grading Scheme',
#  'AR - Created - Academic transcripts for prior tertiary studies',
#  'AR - Created - Academic transcripts incomplete',
#  'AR - Created - Advanced Standing',
#  'AR - Created - Advanced standing application',
#  'AR - Created - Agent Forms: Missing both Forms',
#  'AR - Created - Any other information',
#  'AR - Created - Appointment of authorised representative',
#  'AR - Created - Assessment information (Coursework) (1)',
#  'AR - Created - Assessment information (Coursework) (2)',
#  'AR - Created - Assessment information (Coursework) (3)',
#  'AR - Created - CHESICC transcript authentication for international students',
#  'AR - Created - Credit for previous study',
#  'AR - Created - Credit for previous study - non-University of Melbourne students',
#  'AR - Created - Current enrolment at the University of Melbourne',
#  'AR - Created - Curriculum Vitae',
#  'AR - Created - Employer reference letter',
#  'AR - Created - English language proficiency',
#  'AR - Created - English language requirements',
#  'AR - Created - Entry Requirement Waiver Outcome',
#  'AR - Created - Entry points (Master of Information Systems)',
#  'AR - Created - Full application for Coursework program (1)',
#  'AR - Created - Full application for Coursework program (2)',
#  'AR - Created - Further information (1)',
#  'AR - Created - Further information (2)',
#  'AR - Created - Further information (3)',
#  'AR - Created - Further information (4)',
#  'AR - Created - Further information (5)',
#  'AR - Created - Further information (7)',
#  'AR - Created - Further information - Agent nomination form',
#  'AR - Created - Further information - CV',
#  'AR - Created - Further information - Document corrupted and cannot be opened',
#  'AR - Created - Further information - Document is unclear and cannot be read',
#  'AR - Created - Further information - Genuine Student Checklist',
#  'AR - Created - Further information - Grading scale required',
#  'AR - Created - Further information - Official Transcripts',
#  'AR - Created - Further information - Pakistan Applicants require an Agent',
#  'AR - Created - Further information - Syllabus required for Engineering Advanced Standing',
#  'AR - Created - Further information - Syllabus required for Prerequisite subject checking.',
#  'AR - Created - Further information - Transcript for subjects taken on Exchange',
#  'AR - Created - Further information - Transcript translation and original language',
#  'AR - Created - Further information - Transcripts for subject credited from previous study',
#  'AR - Created - Further information 6 semesters worth of results required',
#  'AR - Created - Further information Pearsons Test of English',
#  'AR - Created - Further information � Preference order required as submitted multiple 1st prefer applications',
#  'AR - Created - Grading scale',
#  'AR - Created - Is your undergraduate degree from a recognised institution and in the same stream as your intended Master of Engineering program?',
#  'AR - Created - No syllabus required',
#  'AR - Created - Official syllabus or subject descriptions (in English)',
#  'AR - Created - Overseas Student Health Cover details',
#  'AR - Created - Passport details',
#  'AR - Created - Payment of international application fee',
#  'AR - Created - Personal statement (500 words)',
#  'AR - Created - Preferred major',
#  'AR - Created - Requirements for Biomedical / Biomedical with Business specialisations',
#  'AR - Created - Specialisation (Master of Engineering)',
#  'AR - Created - Specialisation (Master of Information Systems)',
#  'AR - Created - Sponsorship arrangements',
#  'AR - Created - Syllabus (Melbourne School of Engineering)',
#  'AR - Created - Syllabus requirements',
#  'AR - Created - Syllabus requirements for Electrical / Electrical with Business:;;Is your undergraduate degree a 4 year Engineering degree from a Washington Accord Accredited program and in the same stream as your intended Master of Engineering program?',
#  'AR - Created - Transcript � CHESICC',
#  'AR - Created - Transcript � My eQuals',
#  'AR - Created - University of Melbourne Statement of Results / transcript',
#  'AR - DO NOT USE - Further information (1)',
#  'AR - Not Satisfied - Academic results for prior tertiary studies',
#  'AR - Not Satisfied - Appointment of authorised representative',
#  'AR - Not Satisfied - Credit for previous study',
#  'AR - Not Satisfied - Current enrolment at the University of Melbourne',
#  'AR - Not Satisfied - Curriculum Vitae and professional experience',
#  'AR - Not Satisfied - Details of authorised representative',
#  'AR - Not Satisfied - Duration of previous degree',
#  'AR - Not Satisfied - English language proficiency',
#  'AR - Not Satisfied - Is your undergraduate degree from a recognised institution and in the same stream as your intended Master of Engineering program?',
#  'AR - Not Satisfied - Official syllabus or subject descriptions (in English)',
#  'AR - Not Satisfied - Specialisation (Master of Information Systems)',
#  'AR - Not Satisfied - Specialisation (Master of Information Technology)',
#  'AR - Not Satisfied - Sponsorship arrangements',
#  'AR - Not Satisfied - Transcript � CHESICC',
#  'AR - Requested - Academic results for prior tertiary studies',
#  'AR - Requested - Academic transcript Grading Scheme',
#  'AR - Requested - Academic transcripts for prior tertiary studies',
#  'AR - Requested - Agent Forms: Missing both Forms',
#  'AR - Requested - Appointment of authorised representative',
#  'AR - Requested - Credit for previous study',
#  'AR - Requested - Credit for previous study - non-University of Melbourne students',
#  'AR - Requested - Curriculum Vitae',
#  'AR - Requested - Curriculum Vitae and professional experience',
#  'AR - Requested - Details of authorised representative',
#  'AR - Requested - Employer reference letter',
#  'AR - Requested - English language proficiency',
#  'AR - Requested - Entry points (Master of Information Systems)',
#  'AR - Requested - Full application for Coursework program (1)',
#  'AR - Requested - Further information (1)',
#  'AR - Requested - Further information (2)',
#  'AR - Requested - Further information (3)',
#  'AR - Requested - Further information (4)',
#  'AR - Requested - Further information (5)',
#  'AR - Requested - Further information (7)',
#  'AR - Requested - Further information - Agent nomination form',
#  'AR - Requested - Further information - CV',
#  'AR - Requested - Further information - Document corrupted and cannot be opened',
#  'AR - Requested - Further information - Genuine Student Checklist',
#  'AR - Requested - Further information - Grading scale required',
#  'AR - Requested - Further information - Official Transcripts',
#  'AR - Requested - Further information - Pakistan Applicants require an Agent',
#  'AR - Requested - Further information - Syllabus required for Engineering Advanced Standing',
#  'AR - Requested - Further information - Syllabus required for Prerequisite subject checking.',
#  'AR - Requested - Further information - Transcript for subjects taken on Exchange',
#  'AR - Requested - Further information - Transcript translation and original language',
#  'AR - Requested - Further information - Transcripts for subject credited from previous study',
#  'AR - Requested - Further information 6 semesters worth of results required',
#  'AR - Requested - Further information Pearsons Test of English',
#  'AR - Requested - Further information � Preference order required as submitted multiple 1st prefer applications',
#  'AR - Requested - Grading scale',
#  'AR - Requested - Is your undergraduate degree from a recognised institution and in the same stream as your intended Master of Engineering program?',
#  'AR - Requested - Master of IT (1 year program) - CV',
#  'AR - Requested - No syllabus required',
#  'AR - Requested - Official syllabus or subject descriptions (in English)',
#  'AR - Requested - Payment of international application fee',
#  'AR - Requested - Personal statement (500 words)',
#  'AR - Requested - Requirements for Biomedical / Biomedical with Business specialisations',
#  'AR - Requested - Requirements for Materials specialisation',
#  'AR - Requested - Specialisation (Master of Engineering)',
#  'AR - Requested - Specialisation (Master of Information Systems)',
#  'AR - Requested - Specialisation (Master of Information Technology)',
#  'AR - Requested - Syllabus (Melbourne School of Engineering)',
#  'AR - Requested - Syllabus requirements',
#  'AR - Requested - Syllabus requirements for Electrical / Electrical with Business:;;Is your undergraduate degree a 4 year Engineering degree from a Washington Accord Accredited program and in the same stream as your intended Master of Engineering program?',
#  'AR - Requested - Transcript � CHESICC',
#  'AR - Reviewed - Academic results for prior tertiary studies',
#  'AR - Reviewed - Advanced Standing',
#  'AR - Reviewed - Appointment of authorised representative',
#  'AR - Reviewed - Assessment information (Coursework) (1)',
#  'AR - Reviewed - Assessment information (Coursework) (2)',
#  'AR - Reviewed - Credit for previous study',
#  'AR - Reviewed - Credit for previous study - non-University of Melbourne students',
#  'AR - Reviewed - Current enrolment at the University of Melbourne',
#  'AR - Reviewed - Curriculum Vitae',
#  'AR - Reviewed - Curriculum Vitae and professional experience',
#  'AR - Reviewed - Details of authorised representative',
#  'AR - Reviewed - Duration of previous degree',
#  'AR - Reviewed - English language proficiency',
#  'AR - Reviewed - English language testing result',
#  'AR - Reviewed - Entry points (Master of Information Systems)',
#  'AR - Reviewed - Entry points (Master of Information Technology)',
#  'AR - Reviewed - Full application for Coursework program (1)',
#  'AR - Reviewed - Further information (1)',
#  'AR - Reviewed - Further information (2)',
#  'AR - Reviewed - Further information - Transcripts for subject credited from previous study',
#  'AR - Reviewed - Grading scale',
#  'AR - Reviewed - Master of Information Systems (1 year program) - CV and employer reference',
#  'AR - Reviewed - No syllabus required',
#  'AR - Reviewed - Official syllabus or subject descriptions (in English)',
#  'AR - Reviewed - Recently completed or currently studying an undergraduate degree.',
#  'AR - Reviewed - Specialisation (Master of Information Systems)',
#  'AR - Reviewed - Specialisation (Master of Information Technology)',
#  'AR - Reviewed - Sponsorship arrangements',
#  'AR - Reviewed - Syllabus requirements',
#  'AR - Reviewed - Transcript � CHESICC',
#  'AR - Reviewed - Transcript � My eQuals',
#  'AR - Reviewed - University of Melbourne Statement of Results / transcript',
#  'AR - Satisfied - Academic referee reports (Staff only)',
#  'AR - Satisfied - Academic results for prior tertiary studies',
#  'AR - Satisfied - Academic transcript Grading Scheme',
#  'AR - Satisfied - Academic transcripts for prior tertiary studies',
#  'AR - Satisfied - Academic transcripts incomplete',
#  'AR - Satisfied - Academic transcripts statement of completion',
#  'AR - Satisfied - Advanced Standing',
#  'AR - Satisfied - Advanced standing application',
#  'AR - Satisfied - Agent Forms: Missing both Forms',
#  'AR - Satisfied - Any other information',
#  'AR - Satisfied - Appointment of authorised representative',
#  'AR - Satisfied - Assessment information (Coursework) (1)',
#  'AR - Satisfied - Assessment information (Coursework) (2)',
#  'AR - Satisfied - Assessment information (Coursework) (3)',
#  'AR - Satisfied - China Higher Education Student Information and Career Centre (CHESICC)',
#  'AR - Satisfied - Credit for previous study',
#  'AR - Satisfied - Credit for previous study - University of Melbourne students',
#  'AR - Satisfied - Credit for previous study - non-University of Melbourne students',
#  'AR - Satisfied - Current enrolment at the University of Melbourne',
#  'AR - Satisfied - Curriculum Vitae',
#  'AR - Satisfied - Curriculum Vitae and professional experience',
#  'AR - Satisfied - Details of authorised representative',
#  'AR - Satisfied - Duration of previous degree',
#  'AR - Satisfied - Employer reference letter',
#  'AR - Satisfied - English language proficiency',
#  'AR - Satisfied - English language testing result',
#  'AR - Satisfied - Entry Requirement Waiver Outcome',
#  'AR - Satisfied - Entry points (Master of Information Systems)',
#  'AR - Satisfied - Entry points (Master of Information Technology)',
#  'AR - Satisfied - Full application for Coursework program (1)',
#  'AR - Satisfied - Full application for Coursework program (2)',
#  'AR - Satisfied - Further information (1)',
#  'AR - Satisfied - Further information (2)',
#  'AR - Satisfied - Further information (3)',
#  'AR - Satisfied - Further information (4)',
#  'AR - Satisfied - Further information (5)',
#  'AR - Satisfied - Further information (7)',
#  'AR - Satisfied - Further information - Agent nomination form',
#  'AR - Satisfied - Further information - CV',
#  'AR - Satisfied - Further information - Document corrupted and cannot be opened',
#  'AR - Satisfied - Further information - Document is unclear and cannot be read',
#  'AR - Satisfied - Further information - Genuine Student Checklist',
#  'AR - Satisfied - Further information - Grading scale required',
#  'AR - Satisfied - Further information - Official Transcripts',
#  'AR - Satisfied - Further information - Pakistan Applicants require an Agent',
#  'AR - Satisfied - Further information - Syllabus required for Engineering Advanced Standing',
#  'AR - Satisfied - Further information - Syllabus required for Prerequisite subject checking.',
#  'AR - Satisfied - Further information - Transcript for subjects taken on Exchange',
#  'AR - Satisfied - Further information - Transcript translation and original language',
#  'AR - Satisfied - Further information - Transcripts for subject credited from previous study',
#  'AR - Satisfied - Further information 6 semesters worth of results required',
#  'AR - Satisfied - Further information Pearsons Test of English',
#  'AR - Satisfied - Further information � Preference order required as submitted multiple 1st prefer applications',
#  'AR - Satisfied - Grading scale',
#  'AR - Satisfied - Guaranteed Entry pathways',
#  'AR - Satisfied - Is your undergraduate degree from a recognised institution and in the same stream as your intended Master of Engineering program?',
#  'AR - Satisfied - No syllabus required',
#  'AR - Satisfied - Official syllabus or subject descriptions (in English)',
#  'AR - Satisfied - Overseas Student Health Cover details',
#  'AR - Satisfied - Passport details',
#  'AR - Satisfied - Payment of international application fee',
#  'AR - Satisfied - Personal statement (500 words)',
#  'AR - Satisfied - Preferred major',
#  'AR - Satisfied - Recently completed or currently studying an undergraduate degree.',
#  'AR - Satisfied - Requirements for Biomedical / Biomedical with Business specialisations',
#  'AR - Satisfied - Requirements for Materials specialisation',
#  'AR - Satisfied - Specialisation (Master of Engineering)',
#  'AR - Satisfied - Specialisation (Master of Information Systems)',
#  'AR - Satisfied - Specialisation (Master of Information Technology)',
#  'AR - Satisfied - Sponsorship arrangements',
#  'AR - Satisfied - Syllabus (Melbourne School of Engineering)',
#  'AR - Satisfied - Syllabus requirements for Electrical / Electrical with Business:;;Is your undergraduate degree a 4 year Engineering degree from a Washington Accord Accredited program and in the same stream as your intended Master of Engineering program?',
#  'AR - Satisfied - Transcript � CHESICC',
#  'AR - Satisfied - Transcript � My eQuals',
#  'AR - Satisfied - University of Melbourne Statement of Results / transcript',
#  'Acacdemic - Assessment Decision - No Decision',
#  'Acacdemic - Assessment Decision - Not Qualified',
#  'Acacdemic - Assessment Decision - Qualified',
#  'Assessment Decision - No Decision',
#  'Assessment Decision - Not Assessed',
#  'Assessment Decision - Not Qualified',
#  'Assessment Decision - Qualified',
#  'Assessment Decision - System Assessed',
#  'Assessment Outcome - Higher Preference Successful',
#  'Assessment Outcome - Ineligible / Withdrawn',
#  'Assessment Outcome - No Outcome Set',
#  'Assessment Outcome - Not Successful',
#  'Assessment Outcome - Successful',
#  'Create Offer',
#  'OC - Created - Assessment information (Coursework) (1)',
#  'OC - Created - CDGDC transcript authentication for international students',
#  'OC - Created - CHESICC transcript authentication for international students',
#  'OC - Created - English language proficiency',
#  'OC - Created - English language requirements',
#  'OC - Created - Evidence of course completion',
#  'OC - Created - Further information (1)',
#  'OC - Created - Further information (3)',
#  'OC - Created - Further information - Grading scale required',
#  'OC - Created - Offer condition (English language requirements)',
#  'OC - Created - Payment of international application fee',
#  'OC - Not Satisfied - CDGDC transcript authentication for international students',
#  'OC - Not Satisfied - English language requirements',
#  'OC - Requested - Further information (3)',
#  'OC - Requested - Payment of international application fee',
#  'OC - Reviewed - CDGDC transcript authentication for international students',
#  'OC - Reviewed - CHESICC transcript authentication for international students',
#  'OC - Reviewed - English language requirements',
#  'OC - Satisfied - Assessment information (Coursework) (1)',
#  'OC - Satisfied - CDGDC transcript authentication for international students',
#  'OC - Satisfied - CHESICC transcript authentication for international students',
#  'OC - Satisfied - English language requirements',
#  'OC - Satisfied - Further information (3)',
#  'OC - Satisfied - Further information - Grading scale required',
#  'OC - Satisfied - Offer condition (English language requirements)',
#  'OC - Satisfied - Payment of international application fee',
#  'Put Triage On-Hold',
#  'Release Offer',
#  'Release Triage Hold',
#  'Send for Assessment',
#  'Submit',
#  'WITHDRAW & LOCK'}

# %%
#store unique CASE_ID
ID_list = df3_WS1T['CASE_ID'].tolist()
unique_ID_list = set(ID_list)
len(unique_ID_list)
# Out:
# 12778

# %%
#create dataframe columns->unique_WRKFLW_TSK_MAP_DETAILED row->unique_ID
df = pd.DataFrame(columns = unique_WRKFLW_TSK_MAP_DETAILED_list, index = unique_ID_list )
df
# Out:
#                       AR - Awaiting External Response - Appointment of authorised representative  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       AR - Satisfied - Credit for previous study  \
# 1046027|392560|611104                                        NaN
# 1016661|354965|553447                                        NaN
# 1159894|547672|838337                                        NaN
# 1105466|473778|727033                                        NaN
# 1071976|431654|668456                                        NaN
# ...                                                          ...
# 1141618|519880|831952                                        NaN
# 976621|301776|478261                                         NaN
# 1009304|362884|565740                                        NaN
# 1137717|514303|788804                                        NaN
# 1136210|512073|785560                                        NaN
#
#                       AR - Satisfied - Assessment information (Coursework) (3)  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       OC - Satisfied - Assessment information (Coursework) (1)  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       AR - Created - Syllabus requirements for Electrical / Electrical with Business:;;Is your undergraduate degree a 4 year Engineering degree from a Washington Accord Accredited program and in the same stream as your intended Master of Engineering program?  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       AR - Satisfied - Further information (2)  \
# 1046027|392560|611104                                      NaN
# 1016661|354965|553447                                      NaN
# 1159894|547672|838337                                      NaN
# 1105466|473778|727033                                      NaN
# 1071976|431654|668456                                      NaN
# ...                                                        ...
# 1141618|519880|831952                                      NaN
# 976621|301776|478261                                       NaN
# 1009304|362884|565740                                      NaN
# 1137717|514303|788804                                      NaN
# 1136210|512073|785560                                      NaN
#
#                       AR - Reviewed - No syllabus required  \
# 1046027|392560|611104                                  NaN
# 1016661|354965|553447                                  NaN
# 1159894|547672|838337                                  NaN
# 1105466|473778|727033                                  NaN
# 1071976|431654|668456                                  NaN
# ...                                                    ...
# 1141618|519880|831952                                  NaN
# 976621|301776|478261                                   NaN
# 1009304|362884|565740                                  NaN
# 1137717|514303|788804                                  NaN
# 1136210|512073|785560                                  NaN
#
#                       AR - Reviewed - Further information (2)  \
# 1046027|392560|611104                                     NaN
# 1016661|354965|553447                                     NaN
# 1159894|547672|838337                                     NaN
# 1105466|473778|727033                                     NaN
# 1071976|431654|668456                                     NaN
# ...                                                       ...
# 1141618|519880|831952                                     NaN
# 976621|301776|478261                                      NaN
# 1009304|362884|565740                                     NaN
# 1137717|514303|788804                                     NaN
# 1136210|512073|785560                                     NaN
#
#                       AR - Satisfied - English language proficiency  \
# 1046027|392560|611104                                           NaN
# 1016661|354965|553447                                           NaN
# 1159894|547672|838337                                           NaN
# 1105466|473778|727033                                           NaN
# 1071976|431654|668456                                           NaN
# ...                                                             ...
# 1141618|519880|831952                                           NaN
# 976621|301776|478261                                            NaN
# 1009304|362884|565740                                           NaN
# 1137717|514303|788804                                           NaN
# 1136210|512073|785560                                           NaN
#
#                       Assessment Decision - Qualified  ...  \
# 1046027|392560|611104                             NaN  ...
# 1016661|354965|553447                             NaN  ...
# 1159894|547672|838337                             NaN  ...
# 1105466|473778|727033                             NaN  ...
# 1071976|431654|668456                             NaN  ...
# ...                                               ...  ...
# 1141618|519880|831952                             NaN  ...
# 976621|301776|478261                              NaN  ...
# 1009304|362884|565740                             NaN  ...
# 1137717|514303|788804                             NaN  ...
# 1136210|512073|785560                             NaN  ...
#
#                       Assessment Outcome - No Outcome Set  \
# 1046027|392560|611104                                 NaN
# 1016661|354965|553447                                 NaN
# 1159894|547672|838337                                 NaN
# 1105466|473778|727033                                 NaN
# 1071976|431654|668456                                 NaN
# ...                                                   ...
# 1141618|519880|831952                                 NaN
# 976621|301776|478261                                  NaN
# 1009304|362884|565740                                 NaN
# 1137717|514303|788804                                 NaN
# 1136210|512073|785560                                 NaN
#
#                       AR - Created - Advanced Standing  \
# 1046027|392560|611104                              NaN
# 1016661|354965|553447                              NaN
# 1159894|547672|838337                              NaN
# 1105466|473778|727033                              NaN
# 1071976|431654|668456                              NaN
# ...                                                ...
# 1141618|519880|831952                              NaN
# 976621|301776|478261                               NaN
# 1009304|362884|565740                              NaN
# 1137717|514303|788804                              NaN
# 1136210|512073|785560                              NaN
#
#                       AR - Not Satisfied - Details of authorised representative  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       AR - Reviewed - Assessment information (Coursework) (1)  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       AR - Reviewed - Assessment information (Coursework) (2)  \
# 1046027|392560|611104                                                NaN
# 1016661|354965|553447                                                NaN
# 1159894|547672|838337                                                NaN
# 1105466|473778|727033                                                NaN
# 1071976|431654|668456                                                NaN
# ...                                                                  ...
# 1141618|519880|831952                                                NaN
# 976621|301776|478261                                                 NaN
# 1009304|362884|565740                                                NaN
# 1137717|514303|788804                                                NaN
# 1136210|512073|785560                                                NaN
#
#                       AR - Reviewed - Transcript � CHESICC  \
# 1046027|392560|611104                                  NaN
# 1016661|354965|553447                                  NaN
# 1159894|547672|838337                                  NaN
# 1105466|473778|727033                                  NaN
# 1071976|431654|668456                                  NaN
# ...                                                    ...
# 1141618|519880|831952                                  NaN
# 976621|301776|478261                                   NaN
# 1009304|362884|565740                                  NaN
# 1137717|514303|788804                                  NaN
# 1136210|512073|785560                                  NaN
#
#                       OC - Created - Further information (1)  \
# 1046027|392560|611104                                    NaN
# 1016661|354965|553447                                    NaN
# 1159894|547672|838337                                    NaN
# 1105466|473778|727033                                    NaN
# 1071976|431654|668456                                    NaN
# ...                                                      ...
# 1141618|519880|831952                                    NaN
# 976621|301776|478261                                     NaN
# 1009304|362884|565740                                    NaN
# 1137717|514303|788804                                    NaN
# 1136210|512073|785560                                    NaN
#
#                       AR - Satisfied - Entry Requirement Waiver Outcome  \
# 1046027|392560|611104                                               NaN
# 1016661|354965|553447                                               NaN
# 1159894|547672|838337                                               NaN
# 1105466|473778|727033                                               NaN
# 1071976|431654|668456                                               NaN
# ...                                                                 ...
# 1141618|519880|831952                                               NaN
# 976621|301776|478261                                                NaN
# 1009304|362884|565740                                               NaN
# 1137717|514303|788804                                               NaN
# 1136210|512073|785560                                               NaN
#
#                       AR - Requested - English language proficiency  \
# 1046027|392560|611104                                           NaN
# 1016661|354965|553447                                           NaN
# 1159894|547672|838337                                           NaN
# 1105466|473778|727033                                           NaN
# 1071976|431654|668456                                           NaN
# ...                                                             ...
# 1141618|519880|831952                                           NaN
# 976621|301776|478261                                            NaN
# 1009304|362884|565740                                           NaN
# 1137717|514303|788804                                           NaN
# 1136210|512073|785560                                           NaN
#
#                       OC - Requested - Further information (3)
# 1046027|392560|611104                                      NaN
# 1016661|354965|553447                                      NaN
# 1159894|547672|838337                                      NaN
# 1105466|473778|727033                                      NaN
# 1071976|431654|668456                                      NaN
# ...                                                        ...
# 1141618|519880|831952                                      NaN
# 976621|301776|478261                                       NaN
# 1009304|362884|565740                                      NaN
# 1137717|514303|788804                                      NaN
# 1136210|512073|785560                                      NaN
#
# [12778 rows x 287 columns]

# %%
#sotre id as key and workflow detail of the id as value into dictionary
from collections import defaultdict
ID_WRKFLW_dict = defaultdict(list)
for i, j in zip(df3_WS1T.CASE_ID,df3_WS1T.WRKFLW_TSK_MAP_DETAILED):
    ID_WRKFLW_dict[i].append(j)
len(ID_WRKFLW_dict)
# Out:
# 12778

# %%
#change the value
for key in ID_WRKFLW_dict.keys():
    for process in ID_WRKFLW_dict[key]:
            df.loc[key, process] = 1
zero_one_table = df.fillna(0)
zero_one_table
# Out:
#                        AR - Awaiting External Response - Appointment of authorised representative  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Satisfied - Credit for previous study  \
# 1046027|392560|611104                                           1
# 1016661|354965|553447                                           1
# 1159894|547672|838337                                           0
# 1105466|473778|727033                                           1
# 1071976|431654|668456                                           1
# ...                                                           ...
# 1141618|519880|831952                                           0
# 976621|301776|478261                                            0
# 1009304|362884|565740                                           1
# 1137717|514303|788804                                           0
# 1136210|512073|785560                                           0
#
#                        AR - Satisfied - Assessment information (Coursework) (3)  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        OC - Satisfied - Assessment information (Coursework) (1)  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Created - Syllabus requirements for Electrical / Electrical with Business:;;Is your undergraduate degree a 4 year Engineering degree from a Washington Accord Accredited program and in the same stream as your intended Master of Engineering program?  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Satisfied - Further information (2)  \
# 1046027|392560|611104                                         0
# 1016661|354965|553447                                         0
# 1159894|547672|838337                                         0
# 1105466|473778|727033                                         0
# 1071976|431654|668456                                         0
# ...                                                         ...
# 1141618|519880|831952                                         0
# 976621|301776|478261                                          0
# 1009304|362884|565740                                         0
# 1137717|514303|788804                                         0
# 1136210|512073|785560                                         0
#
#                        AR - Reviewed - No syllabus required  \
# 1046027|392560|611104                                     0
# 1016661|354965|553447                                     0
# 1159894|547672|838337                                     0
# 1105466|473778|727033                                     0
# 1071976|431654|668456                                     0
# ...                                                     ...
# 1141618|519880|831952                                     0
# 976621|301776|478261                                      0
# 1009304|362884|565740                                     0
# 1137717|514303|788804                                     0
# 1136210|512073|785560                                     0
#
#                        AR - Reviewed - Further information (2)  \
# 1046027|392560|611104                                        0
# 1016661|354965|553447                                        0
# 1159894|547672|838337                                        0
# 1105466|473778|727033                                        0
# 1071976|431654|668456                                        0
# ...                                                        ...
# 1141618|519880|831952                                        0
# 976621|301776|478261                                         0
# 1009304|362884|565740                                        0
# 1137717|514303|788804                                        0
# 1136210|512073|785560                                        0
#
#                        AR - Satisfied - English language proficiency  \
# 1046027|392560|611104                                              1
# 1016661|354965|553447                                              1
# 1159894|547672|838337                                              1
# 1105466|473778|727033                                              0
# 1071976|431654|668456                                              1
# ...                                                              ...
# 1141618|519880|831952                                              0
# 976621|301776|478261                                               0
# 1009304|362884|565740                                              1
# 1137717|514303|788804                                              0
# 1136210|512073|785560                                              1
#
#                        Assessment Decision - Qualified  ...  \
# 1046027|392560|611104                                0  ...
# 1016661|354965|553447                                0  ...
# 1159894|547672|838337                                0  ...
# 1105466|473778|727033                                1  ...
# 1071976|431654|668456                                1  ...
# ...                                                ...  ...
# 1141618|519880|831952                                0  ...
# 976621|301776|478261                                 0  ...
# 1009304|362884|565740                                1  ...
# 1137717|514303|788804                                0  ...
# 1136210|512073|785560                                1  ...
#
#                        Assessment Outcome - No Outcome Set  \
# 1046027|392560|611104                                    0
# 1016661|354965|553447                                    0
# 1159894|547672|838337                                    0
# 1105466|473778|727033                                    0
# 1071976|431654|668456                                    0
# ...                                                    ...
# 1141618|519880|831952                                    0
# 976621|301776|478261                                     0
# 1009304|362884|565740                                    0
# 1137717|514303|788804                                    0
# 1136210|512073|785560                                    0
#
#                        AR - Created - Advanced Standing  \
# 1046027|392560|611104                                 0
# 1016661|354965|553447                                 0
# 1159894|547672|838337                                 0
# 1105466|473778|727033                                 0
# 1071976|431654|668456                                 0
# ...                                                 ...
# 1141618|519880|831952                                 0
# 976621|301776|478261                                  0
# 1009304|362884|565740                                 0
# 1137717|514303|788804                                 0
# 1136210|512073|785560                                 0
#
#                        AR - Not Satisfied - Details of authorised representative  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Reviewed - Assessment information (Coursework) (1)  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Reviewed - Assessment information (Coursework) (2)  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Reviewed - Transcript � CHESICC  \
# 1046027|392560|611104                                     0
# 1016661|354965|553447                                     0
# 1159894|547672|838337                                     0
# 1105466|473778|727033                                     0
# 1071976|431654|668456                                     0
# ...                                                     ...
# 1141618|519880|831952                                     0
# 976621|301776|478261                                      0
# 1009304|362884|565740                                     0
# 1137717|514303|788804                                     0
# 1136210|512073|785560                                     0
#
#                        OC - Created - Further information (1)  \
# 1046027|392560|611104                                       0
# 1016661|354965|553447                                       0
# 1159894|547672|838337                                       0
# 1105466|473778|727033                                       0
# 1071976|431654|668456                                       0
# ...                                                       ...
# 1141618|519880|831952                                       0
# 976621|301776|478261                                        0
# 1009304|362884|565740                                       0
# 1137717|514303|788804                                       0
# 1136210|512073|785560                                       0
#
#                        AR - Satisfied - Entry Requirement Waiver Outcome  \
# 1046027|392560|611104                                                  0
# 1016661|354965|553447                                                  0
# 1159894|547672|838337                                                  0
# 1105466|473778|727033                                                  0
# 1071976|431654|668456                                                  0
# ...                                                                  ...
# 1141618|519880|831952                                                  0
# 976621|301776|478261                                                   0
# 1009304|362884|565740                                                  0
# 1137717|514303|788804                                                  0
# 1136210|512073|785560                                                  0
#
#                        AR - Requested - English language proficiency  \
# 1046027|392560|611104                                              0
# 1016661|354965|553447                                              0
# 1159894|547672|838337                                              0
# 1105466|473778|727033                                              0
# 1071976|431654|668456                                              0
# ...                                                              ...
# 1141618|519880|831952                                              0
# 976621|301776|478261                                               0
# 1009304|362884|565740                                              0
# 1137717|514303|788804                                              0
# 1136210|512073|785560                                              0
#
#                        OC - Requested - Further information (3)
# 1046027|392560|611104                                         0
# 1016661|354965|553447                                         0
# 1159894|547672|838337                                         0
# 1105466|473778|727033                                         0
# 1071976|431654|668456                                         0
# ...                                                         ...
# 1141618|519880|831952                                         0
# 976621|301776|478261                                          0
# 1009304|362884|565740                                         0
# 1137717|514303|788804                                         0
# 1136210|512073|785560                                         0
#
# [12778 rows x 287 columns]

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

features= list(unique_WRKFLW_TSK_MAP_DETAILED_list)
print(len(features))
features.remove('Send for Assessment')
print(len(features))

X=zero_one_table[features]
y=zero_one_table ['Send for Assessment'] # Labels
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # 70% training and 30% test
# Out:
# 287
# 286

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 3,
                             random_state = 0)
clf.fit(X_train, y_train)
clf_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
# Generate the confusion matrix and classification report
print(confusion_matrix(y_test, clf_pred))
print(classification_report(y_test, clf_pred))
# Out:
# [[ 117  277]
#  [   7 2794]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.30      0.45       394
#            1       0.91      1.00      0.95      2801
#
#     accuracy                           0.91      3195
#    macro avg       0.93      0.65      0.70      3195
# weighted avg       0.91      0.91      0.89      3195

# %%
# DOT data
from IPython.display import Image
from sklearn import tree
import pydotplus
fn=features
cn=['0', '1']
# Create DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=fn,
                                class_names=cn,filled = True)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
# Show graph
Image(graph.create_png())

# %%
# Create PNG
graph.write_png("engineering_OF_segment1_workflowS1_decisiontree.png")
# Out:
# True

# %%
zero_one_table['Send for Assessment'].value_counts()
# Out:
# 1    11217
# 0     1561
# Name: Send for Assessment, dtype: int64

# %%
from sklearn.utils import resample

# Separate majority and minority classes
zero_one_table_majority = df[zero_one_table['Send for Assessment']==1]
zero_one_table_minority = df[zero_one_table['Send for Assessment']==0]

# Upsample minority class
df_majority_downsampled = resample(zero_one_table_majority,
                                 replace=False,     # sample with replacement
                                 n_samples=1561,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_downsampled = pd.concat([zero_one_table_minority, df_majority_downsampled])

# Display new class counts
df_downsampled = df_downsampled.fillna(0)
df_downsampled['Send for Assessment'].value_counts()
# Out:
# 1    1561
# 0    1561
# Name: Send for Assessment, dtype: int64

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X=df_downsampled[features]
y=df_downsampled ['Send for Assessment'] # Labels
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # 70% training and 30% test

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 3,
                             random_state = 0)
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9001280409731114

# %%
# Generate the confusion matrix and classification report
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[398  21]
#  [ 57 305]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       419
#            1       0.94      0.84      0.89       362
#
#     accuracy                           0.90       781
#    macro avg       0.91      0.90      0.90       781
# weighted avg       0.90      0.90      0.90       781

# %%
# DOT data
from IPython.display import Image
from sklearn import tree
import pydotplus
fn=features
cn=['0', '1']
# Create DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=fn,
                                class_names=cn,filled = True)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
# Show graph
Image(graph.create_png())

# %%
# Create PNG
graph.write_png("engineering_OF_segment1_workflowS1_decisiontree_downsampled.png")
# Out:
# True
