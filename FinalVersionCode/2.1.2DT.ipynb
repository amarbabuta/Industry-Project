# %%
import pandas as pd

# %%
df3_WS1T = pd.read_csv("engineering_OF_segment1_workflowS2_has_duration.csv",engine='python')

# %%
df3_WS1T.head(n=1)
# Out:
#                 CASE_ID WRKFLW_TSK_MAP_GROUPED WRKFLW_TSK_MAP_DETAILED  \
# 0  715808|405750|629365    Send for Assessment     Send for Assessment
#
#       PATH_CRDATETIME                          time_used_str  time_used_second
# 0  24/10/2018 9:36:47  14 days 5 hours 50 minutes 45 seconds         1230645.0

# %%
#store unique WRKFLW_TSK_MAP_DETAILED
WRKFLW_TSK_MAP_DETAILED_list = df3_WS1T['WRKFLW_TSK_MAP_DETAILED'].tolist()
unique_WRKFLW_TSK_MAP_DETAILED_list = set(WRKFLW_TSK_MAP_DETAILED_list)
len(unique_WRKFLW_TSK_MAP_DETAILED_list)
unique_WRKFLW_TSK_MAP_DETAILED_list
# Out:
# {'AR - Created - Acceptance agreement (International)',
#  'AR - Created - Advanced standing application',
#  'AR - Created - Assessment information (Coursework) (1)',
#  'AR - Created - Assessment information (Coursework) (2)',
#  'AR - Created - CONDITIONAL Acceptance agreement (International)',
#  'AR - Created - Credit for previous study',
#  'AR - Created - Credit for previous study - non-University of Melbourne students',
#  'AR - Created - Curriculum Vitae',
#  'AR - Created - Entry points (Master of Information Systems)',
#  'AR - Created - Evidence of course completion',
#  'AR - Created - Full application for Coursework program (1)',
#  'AR - Created - Further information (1)',
#  'AR - Created - Further information (2)',
#  'AR - Created - Further information (3)',
#  'AR - Created - Further information (4)',
#  'AR - Created - Further information - Agent nomination form',
#  'AR - Created - Further information - Pakistan Applicants require an Agent',
#  'AR - Created - Further information - Syllabus required for Engineering Advanced Standing',
#  'AR - Created - Further information - Transcript translation and original language',
#  'AR - Created - Further information 6 semesters worth of results required',
#  'AR - Created - Further information � Preference order required as submitted multiple 1st prefer applications',
#  'AR - Created - Grading scale',
#  'AR - Created - Is your undergraduate degree from a recognised institution and in the same stream as your intended Master of Engineering program?',
#  'AR - Created - Official syllabus or subject descriptions (in English)',
#  'AR - Created - Overseas Student Health Cover details',
#  'AR - Created - Passport details',
#  'AR - Created - Payment of international application fee',
#  'AR - Created - Personal statement',
#  'AR - Created - Requirements for Biomedical / Biomedical with Business specialisations',
#  'AR - Created - Specialisation (Master of Engineering)',
#  'AR - Created - Specialisation (Master of Information Systems)',
#  'AR - Created - Syllabus (Melbourne School of Engineering)',
#  'AR - Created - Syllabus requirements',
#  'AR - Created - University of Melbourne Statement of Results / transcript',
#  'AR - Not Satisfied - Academic results for prior tertiary studies',
#  'AR - Not Satisfied - Appointment of authorised representative',
#  'AR - Not Satisfied - Credit for previous study',
#  'AR - Not Satisfied - Curriculum Vitae and professional experience',
#  'AR - Not Satisfied - English language proficiency',
#  'AR - Not Satisfied - Further information (1)',
#  'AR - Not Satisfied - Official syllabus or subject descriptions (in English)',
#  'AR - Not Satisfied - Requirements for Biomedical / Biomedical with Business specialisations',
#  'AR - Requested - Academic results for prior tertiary studies',
#  'AR - Requested - Acceptance agreement (International)',
#  'AR - Requested - Appointment of authorised representative',
#  'AR - Requested - Assessment information (Coursework) (1)',
#  'AR - Requested - Credit for previous study',
#  'AR - Requested - English language proficiency',
#  'AR - Requested - Entry points (Master of Information Systems)',
#  'AR - Requested - Further information (1)',
#  'AR - Requested - Further information (2)',
#  'AR - Requested - Further information (3)',
#  'AR - Requested - Further information - Pakistan Applicants require an Agent',
#  'AR - Requested - Further information - Syllabus required for Engineering Advanced Standing',
#  'AR - Requested - Further information 6 semesters worth of results required',
#  'AR - Requested - Further information � Preference order required as submitted multiple 1st prefer applications',
#  'AR - Requested - Grading scale',
#  'AR - Requested - Official syllabus or subject descriptions (in English)',
#  'AR - Requested - Payment of international application fee',
#  'AR - Requested - Specialisation (Master of Engineering)',
#  'AR - Reviewed - Academic results for prior tertiary studies',
#  'AR - Reviewed - Advanced Standing',
#  'AR - Reviewed - Appointment of authorised representative',
#  'AR - Reviewed - Assessment information (Coursework) (1)',
#  'AR - Reviewed - Credit for previous study',
#  'AR - Reviewed - Current enrolment at the University of Melbourne',
#  'AR - Reviewed - Details of authorised representative',
#  'AR - Reviewed - English language proficiency',
#  'AR - Reviewed - Entry points (Master of Information Systems)',
#  'AR - Reviewed - Entry points (Master of Information Technology)',
#  'AR - Reviewed - Full application for Coursework program (1)',
#  'AR - Reviewed - Further information (1)',
#  'AR - Reviewed - Further information (2)',
#  'AR - Reviewed - Official syllabus or subject descriptions (in English)',
#  'AR - Reviewed - Overseas Student Health Cover details',
#  'AR - Reviewed - Requirements for Materials specialisation',
#  'AR - Reviewed - Specialisation (Master of Information Systems)',
#  'AR - Reviewed - Specialisation (Master of Information Technology)',
#  'AR - Reviewed - Sponsorship arrangements',
#  'AR - Satisfied - Academic results for prior tertiary studies',
#  'AR - Satisfied - Academic transcripts for prior tertiary studies',
#  'AR - Satisfied - Acceptance agreement (International)',
#  'AR - Satisfied - Advanced Standing',
#  'AR - Satisfied - Advanced standing application',
#  'AR - Satisfied - Appointment of authorised representative',
#  'AR - Satisfied - Assessment information (Coursework) (1)',
#  'AR - Satisfied - Assessment information (Coursework) (2)',
#  'AR - Satisfied - CONDITIONAL Acceptance agreement (International)',
#  'AR - Satisfied - Credit for previous study',
#  'AR - Satisfied - Current enrolment at the University of Melbourne',
#  'AR - Satisfied - Curriculum Vitae',
#  'AR - Satisfied - Curriculum Vitae and professional experience',
#  'AR - Satisfied - Details of authorised representative',
#  'AR - Satisfied - Duration of previous degree',
#  'AR - Satisfied - Employer reference letter',
#  'AR - Satisfied - English language proficiency',
#  'AR - Satisfied - English language requirements',
#  'AR - Satisfied - Entry points (Master of Information Systems)',
#  'AR - Satisfied - Entry points (Master of Information Technology)',
#  'AR - Satisfied - Evidence of course completion',
#  'AR - Satisfied - Full application for Coursework program (1)',
#  'AR - Satisfied - Further information (1)',
#  'AR - Satisfied - Further information (2)',
#  'AR - Satisfied - Further information (3)',
#  'AR - Satisfied - Further information (4)',
#  'AR - Satisfied - Further information (5)',
#  'AR - Satisfied - Further information - Agent nomination form',
#  'AR - Satisfied - Further information - Genuine Student Checklist',
#  'AR - Satisfied - Further information - Syllabus required for Engineering Advanced Standing',
#  'AR - Satisfied - Further information - Transcript translation and original language',
#  'AR - Satisfied - Further information � Preference order required as submitted multiple 1st prefer applications',
#  'AR - Satisfied - Grading scale',
#  'AR - Satisfied - Official syllabus or subject descriptions (in English)',
#  'AR - Satisfied - Overseas Student Health Cover details',
#  'AR - Satisfied - Payment of international application fee',
#  'AR - Satisfied - Personal statement',
#  'AR - Satisfied - Requirements for Biomedical / Biomedical with Business specialisations',
#  'AR - Satisfied - Specialisation (Master of Engineering)',
#  'AR - Satisfied - Specialisation (Master of Information Systems)',
#  'AR - Satisfied - Specialisation (Master of Information Technology)',
#  'AR - Satisfied - Sponsorship arrangements',
#  'AR - Satisfied - Syllabus (Melbourne School of Engineering)',
#  'AR - Satisfied - Syllabus requirements for Electrical / Electrical with Business:;;Is your undergraduate degree a 4 year Engineering degree from a Washington Accord Accredited program and in the same stream as your intended Master of Engineering program?',
#  'AR - Satisfied - Transcript � CHESICC',
#  'AR - Satisfied - Transcript � My eQuals',
#  'AR - Satisfied - University of Melbourne Statement of Results / transcript',
#  'Acacdemic - Assessment Decision - Interview Required',
#  'Acacdemic - Assessment Decision - No Decision',
#  'Acacdemic - Assessment Decision - Not Qualified',
#  'Acacdemic - Assessment Decision - Qualified',
#  'Acacdemic - Assessment Outcome - Higher Preference Successful',
#  'Acacdemic - Assessment Outcome - No Outcome Set',
#  'Acacdemic - Assessment Outcome - Not Successful',
#  'Acacdemic - Assessment Outcome - Successful',
#  'Assessment Decision - No Decision',
#  'Assessment Decision - Not Assessed',
#  'Assessment Decision - Not Qualified',
#  'Assessment Decision - Qualified',
#  'Assessment Decision - System Assessed',
#  'Assessment Outcome - DO NOT USE',
#  'Assessment Outcome - Higher Preference Successful',
#  'Assessment Outcome - Ineligible / Withdrawn',
#  'Assessment Outcome - Not Successful',
#  'Assessment Outcome - Successful',
#  'Back to Perform Assessment',
#  'Back to Triage',
#  'Cancel Referral',
#  'Close Referral',
#  'Create Offer',
#  'End My Assessment',
#  'OC - Awaiting External Response - Evidence of course completion',
#  'OC - Created - CDGDC transcript authentication for international students',
#  'OC - Created - CHESICC transcript authentication for international students',
#  'OC - Created - English language requirements',
#  'OC - Created - Evidence of course completion',
#  'OC - Created - Evidence of work experience',
#  'OC - Created - Further information (1)',
#  'OC - Created - Further information (2)',
#  'OC - Created - Further information (3)',
#  'OC - Created - Further information - Official Transcripts',
#  'OC - Created - Payment of international application fee',
#  'OC - Created - UMELBP (H3)',
#  'OC - Not Satisfied - English language requirements',
#  'OC - Not Satisfied - Evidence of course completion',
#  'OC - Requested - CHESICC transcript authentication for international students',
#  'OC - Requested - English language requirements',
#  'OC - Requested - Evidence of course completion',
#  'OC - Reviewed - CHESICC transcript authentication for international students',
#  'OC - Reviewed - English language requirements',
#  'OC - Reviewed - Evidence of course completion',
#  'OC - Satisfied - CDGDC transcript authentication for international students',
#  'OC - Satisfied - CHESICC transcript authentication for international students',
#  'OC - Satisfied - English language requirements',
#  'OC - Satisfied - Evidence of course completion',
#  'OC - Satisfied - UMELBP (H3)',
#  'PREPARE TO LOCK',
#  'Provide Response',
#  'Put Assessment On-Hold',
#  'Put Triage On-Hold',
#  'Release Assessment Hold',
#  'Release Triage Hold',
#  'Send Referral',
#  'Send for Assessment',
#  'WITHDRAW & LOCK'}

# %%
#store unique CASE_ID
ID_list = df3_WS1T['CASE_ID'].tolist()
unique_ID_list = set(ID_list)
len(unique_ID_list)
# Out:
# 10262

# %%
#create dataframe columns->unique_WRKFLW_TSK_MAP_DETAILED row->unique_ID
df = pd.DataFrame(columns = unique_WRKFLW_TSK_MAP_DETAILED_list, index = unique_ID_list )
df
# Out:
#                       AR - Satisfied - Advanced standing application  \
# 1068485|426112|660313                                            NaN
# 1109931|478711|734367                                            NaN
# 1043146|388829|605537                                            NaN
# 1036527|380521|592771                                            NaN
# 1069531|427734|662744                                            NaN
# ...                                                              ...
# 708335|422404|654198                                             NaN
# 1047865|394924|614585                                            NaN
# 1164519|554500|848156                                            NaN
# 1091544|463408|711814                                            NaN
# 852955|520883|798719                                             NaN
#
#                       Release Triage Hold  \
# 1068485|426112|660313                 NaN
# 1109931|478711|734367                 NaN
# 1043146|388829|605537                 NaN
# 1036527|380521|592771                 NaN
# 1069531|427734|662744                 NaN
# ...                                   ...
# 708335|422404|654198                  NaN
# 1047865|394924|614585                 NaN
# 1164519|554500|848156                 NaN
# 1091544|463408|711814                 NaN
# 852955|520883|798719                  NaN
#
#                       AR - Requested - Academic results for prior tertiary studies  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       OC - Satisfied - English language requirements  \
# 1068485|426112|660313                                            NaN
# 1109931|478711|734367                                            NaN
# 1043146|388829|605537                                            NaN
# 1036527|380521|592771                                            NaN
# 1069531|427734|662744                                            NaN
# ...                                                              ...
# 708335|422404|654198                                             NaN
# 1047865|394924|614585                                            NaN
# 1164519|554500|848156                                            NaN
# 1091544|463408|711814                                            NaN
# 852955|520883|798719                                             NaN
#
#                       AR - Requested - Entry points (Master of Information Systems)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       AR - Satisfied - English language proficiency  \
# 1068485|426112|660313                                           NaN
# 1109931|478711|734367                                           NaN
# 1043146|388829|605537                                           NaN
# 1036527|380521|592771                                           NaN
# 1069531|427734|662744                                           NaN
# ...                                                             ...
# 708335|422404|654198                                            NaN
# 1047865|394924|614585                                           NaN
# 1164519|554500|848156                                           NaN
# 1091544|463408|711814                                           NaN
# 852955|520883|798719                                            NaN
#
#                       AR - Satisfied - Curriculum Vitae and professional experience  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       Close Referral  \
# 1068485|426112|660313            NaN
# 1109931|478711|734367            NaN
# 1043146|388829|605537            NaN
# 1036527|380521|592771            NaN
# 1069531|427734|662744            NaN
# ...                              ...
# 708335|422404|654198             NaN
# 1047865|394924|614585            NaN
# 1164519|554500|848156            NaN
# 1091544|463408|711814            NaN
# 852955|520883|798719             NaN
#
#                       AR - Reviewed - Assessment information (Coursework) (1)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       AR - Reviewed - Further information (2)  ...  \
# 1068485|426112|660313                                     NaN  ...
# 1109931|478711|734367                                     NaN  ...
# 1043146|388829|605537                                     NaN  ...
# 1036527|380521|592771                                     NaN  ...
# 1069531|427734|662744                                     NaN  ...
# ...                                                       ...  ...
# 708335|422404|654198                                      NaN  ...
# 1047865|394924|614585                                     NaN  ...
# 1164519|554500|848156                                     NaN  ...
# 1091544|463408|711814                                     NaN  ...
# 852955|520883|798719                                      NaN  ...
#
#                       AR - Satisfied - CONDITIONAL Acceptance agreement (International)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       AR - Requested - Grading scale  \
# 1068485|426112|660313                            NaN
# 1109931|478711|734367                            NaN
# 1043146|388829|605537                            NaN
# 1036527|380521|592771                            NaN
# 1069531|427734|662744                            NaN
# ...                                              ...
# 708335|422404|654198                             NaN
# 1047865|394924|614585                            NaN
# 1164519|554500|848156                            NaN
# 1091544|463408|711814                            NaN
# 852955|520883|798719                             NaN
#
#                       AR - Created - Specialisation (Master of Information Systems)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       AR - Satisfied - Curriculum Vitae  \
# 1068485|426112|660313                               NaN
# 1109931|478711|734367                               NaN
# 1043146|388829|605537                               NaN
# 1036527|380521|592771                               NaN
# 1069531|427734|662744                               NaN
# ...                                                 ...
# 708335|422404|654198                                NaN
# 1047865|394924|614585                               NaN
# 1164519|554500|848156                               NaN
# 1091544|463408|711814                               NaN
# 852955|520883|798719                                NaN
#
#                       OC - Requested - English language requirements  \
# 1068485|426112|660313                                            NaN
# 1109931|478711|734367                                            NaN
# 1043146|388829|605537                                            NaN
# 1036527|380521|592771                                            NaN
# 1069531|427734|662744                                            NaN
# ...                                                              ...
# 708335|422404|654198                                             NaN
# 1047865|394924|614585                                            NaN
# 1164519|554500|848156                                            NaN
# 1091544|463408|711814                                            NaN
# 852955|520883|798719                                             NaN
#
#                       AR - Satisfied - Entry points (Master of Information Systems)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       AR - Satisfied - Specialisation (Master of Information Technology)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       AR - Created - Full application for Coursework program (1)  \
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
#                       Assessment Decision - Qualified  \
# 1068485|426112|660313                             NaN
# 1109931|478711|734367                             NaN
# 1043146|388829|605537                             NaN
# 1036527|380521|592771                             NaN
# 1069531|427734|662744                             NaN
# ...                                               ...
# 708335|422404|654198                              NaN
# 1047865|394924|614585                             NaN
# 1164519|554500|848156                             NaN
# 1091544|463408|711814                             NaN
# 852955|520883|798719                              NaN
#
#                       OC - Created - Further information - Official Transcripts
# 1068485|426112|660313                                                NaN
# 1109931|478711|734367                                                NaN
# 1043146|388829|605537                                                NaN
# 1036527|380521|592771                                                NaN
# 1069531|427734|662744                                                NaN
# ...                                                                  ...
# 708335|422404|654198                                                 NaN
# 1047865|394924|614585                                                NaN
# 1164519|554500|848156                                                NaN
# 1091544|463408|711814                                                NaN
# 852955|520883|798719                                                 NaN
#
# [10262 rows x 184 columns]

# %%
#sotre id as key and workflow detail of the id as value into dictionary
from collections import defaultdict
ID_WRKFLW_dict = defaultdict(list)
for i, j in zip(df3_WS1T.CASE_ID,df3_WS1T.WRKFLW_TSK_MAP_DETAILED):
    ID_WRKFLW_dict[i].append(j)
len(ID_WRKFLW_dict)
# Out:
# 10262

# %%
#change the value
for key in ID_WRKFLW_dict.keys():
    for process in ID_WRKFLW_dict[key]:
            df.loc[key, process] = 1
zero_one_table = df.fillna(0)
zero_one_table
# Out:
#                        AR - Satisfied - Advanced standing application  \
# 1068485|426112|660313                                               0
# 1109931|478711|734367                                               0
# 1043146|388829|605537                                               0
# 1036527|380521|592771                                               0
# 1069531|427734|662744                                               0
# ...                                                               ...
# 708335|422404|654198                                                0
# 1047865|394924|614585                                               0
# 1164519|554500|848156                                               0
# 1091544|463408|711814                                               0
# 852955|520883|798719                                                0
#
#                        Release Triage Hold  \
# 1068485|426112|660313                    0
# 1109931|478711|734367                    0
# 1043146|388829|605537                    0
# 1036527|380521|592771                    0
# 1069531|427734|662744                    0
# ...                                    ...
# 708335|422404|654198                     0
# 1047865|394924|614585                    0
# 1164519|554500|848156                    0
# 1091544|463408|711814                    0
# 852955|520883|798719                     0
#
#                        AR - Requested - Academic results for prior tertiary studies  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        OC - Satisfied - English language requirements  \
# 1068485|426112|660313                                               0
# 1109931|478711|734367                                               0
# 1043146|388829|605537                                               0
# 1036527|380521|592771                                               0
# 1069531|427734|662744                                               0
# ...                                                               ...
# 708335|422404|654198                                                0
# 1047865|394924|614585                                               0
# 1164519|554500|848156                                               0
# 1091544|463408|711814                                               0
# 852955|520883|798719                                                0
#
#                        AR - Requested - Entry points (Master of Information Systems)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        AR - Satisfied - English language proficiency  \
# 1068485|426112|660313                                              0
# 1109931|478711|734367                                              0
# 1043146|388829|605537                                              0
# 1036527|380521|592771                                              0
# 1069531|427734|662744                                              0
# ...                                                              ...
# 708335|422404|654198                                               0
# 1047865|394924|614585                                              0
# 1164519|554500|848156                                              0
# 1091544|463408|711814                                              0
# 852955|520883|798719                                               0
#
#                        AR - Satisfied - Curriculum Vitae and professional experience  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        Close Referral  \
# 1068485|426112|660313               0
# 1109931|478711|734367               0
# 1043146|388829|605537               0
# 1036527|380521|592771               0
# 1069531|427734|662744               0
# ...                               ...
# 708335|422404|654198                0
# 1047865|394924|614585               0
# 1164519|554500|848156               0
# 1091544|463408|711814               0
# 852955|520883|798719                0
#
#                        AR - Reviewed - Assessment information (Coursework) (1)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        AR - Reviewed - Further information (2)  ...  \
# 1068485|426112|660313                                        0  ...
# 1109931|478711|734367                                        0  ...
# 1043146|388829|605537                                        0  ...
# 1036527|380521|592771                                        0  ...
# 1069531|427734|662744                                        0  ...
# ...                                                        ...  ...
# 708335|422404|654198                                         0  ...
# 1047865|394924|614585                                        0  ...
# 1164519|554500|848156                                        0  ...
# 1091544|463408|711814                                        0  ...
# 852955|520883|798719                                         0  ...
#
#                        AR - Satisfied - CONDITIONAL Acceptance agreement (International)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        AR - Requested - Grading scale  \
# 1068485|426112|660313                               0
# 1109931|478711|734367                               0
# 1043146|388829|605537                               0
# 1036527|380521|592771                               0
# 1069531|427734|662744                               0
# ...                                               ...
# 708335|422404|654198                                0
# 1047865|394924|614585                               0
# 1164519|554500|848156                               0
# 1091544|463408|711814                               0
# 852955|520883|798719                                0
#
#                        AR - Created - Specialisation (Master of Information Systems)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        AR - Satisfied - Curriculum Vitae  \
# 1068485|426112|660313                                  0
# 1109931|478711|734367                                  0
# 1043146|388829|605537                                  0
# 1036527|380521|592771                                  0
# 1069531|427734|662744                                  0
# ...                                                  ...
# 708335|422404|654198                                   0
# 1047865|394924|614585                                  0
# 1164519|554500|848156                                  0
# 1091544|463408|711814                                  0
# 852955|520883|798719                                   0
#
#                        OC - Requested - English language requirements  \
# 1068485|426112|660313                                               0
# 1109931|478711|734367                                               0
# 1043146|388829|605537                                               0
# 1036527|380521|592771                                               0
# 1069531|427734|662744                                               0
# ...                                                               ...
# 708335|422404|654198                                                0
# 1047865|394924|614585                                               0
# 1164519|554500|848156                                               0
# 1091544|463408|711814                                               0
# 852955|520883|798719                                                0
#
#                        AR - Satisfied - Entry points (Master of Information Systems)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        AR - Satisfied - Specialisation (Master of Information Technology)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        AR - Created - Full application for Coursework program (1)  \
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
#                        Assessment Decision - Qualified  \
# 1068485|426112|660313                                0
# 1109931|478711|734367                                0
# 1043146|388829|605537                                1
# 1036527|380521|592771                                0
# 1069531|427734|662744                                1
# ...                                                ...
# 708335|422404|654198                                 0
# 1047865|394924|614585                                1
# 1164519|554500|848156                                0
# 1091544|463408|711814                                0
# 852955|520883|798719                                 0
#
#                        OC - Created - Further information - Official Transcripts
# 1068485|426112|660313                                                  0
# 1109931|478711|734367                                                  0
# 1043146|388829|605537                                                  0
# 1036527|380521|592771                                                  0
# 1069531|427734|662744                                                  0
# ...                                                                  ...
# 708335|422404|654198                                                   0
# 1047865|394924|614585                                                  0
# 1164519|554500|848156                                                  0
# 1091544|463408|711814                                                  0
# 852955|520883|798719                                                   0
#
# [10262 rows x 184 columns]

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

features= list(unique_WRKFLW_TSK_MAP_DETAILED_list)
print(len(features))
features.remove('Assessment Outcome - Successful')
features.remove('Assessment Outcome - Not Successful')
print(len(features))

X=zero_one_table[features]
y=zero_one_table ['Assessment Outcome - Successful'] # Labels
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # 70% training and 30% test
# Out:
# 184
# 182

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
# Setup the parameters and distributions to sample from: param_dist
param_dist = {"max_depth": [1, 2, 3, 4, 5, 6, 7, 8, 9],
"max_features": randint(1, 9),
"min_samples_leaf": randint(1, 9),
"criterion": ["gini", "entropy"]}
# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()
# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_dist, cv=5)
# Fit it to the data
tree_cv.fit(X_train,y_train)
# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 6}
# Best score is 0.6900829514864603

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
DecisionTreeClassifier(class_weight=None, criterion="gini", max_depth=None,
                       max_features=None, max_leaf_nodes=None, min_impurity_split=1e-07, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0, presort=False, 
                       random_state=None, splitter="best")
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9062381183506844

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
    dt = DecisionTreeClassifier(max_depth=max_depth)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    # Add auc score to previous train results
    train_results.append(roc_auc)
    y_pred = dt.predict(X_test)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    # Add auc score to previous test results
    test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, "b", label="Train AUC")
line2, = plt.plot(max_depths, test_results, "r", label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel("AUC score")
plt.xlabel("Tree depth")
plt.show()

# %%
clf = DecisionTreeClassifier(max_depth = 5,
                             random_state = 0)
clf.fit(X_train, y_train)
clf_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
# Generate the confusion matrix and classification report
print(confusion_matrix(y_test, clf_pred))
print(classification_report(y_test, clf_pred))
# Out:
# [[ 898   91]
#  [ 142 1435]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89       989
#            1       0.94      0.91      0.92      1577
#
#     accuracy                           0.91      2566
#    macro avg       0.90      0.91      0.91      2566
# weighted avg       0.91      0.91      0.91      2566

# %%
# DOT data
from IPython.display import Image
from sklearn import tree
import pydotplus
fn=features
cn=['0', '1']
# Create DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=fn,
                                class_names=cn,filled = True)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
# Show graph
Image(graph.create_png())

# %%
# Create PNG
graph.write_png("engineering_OF_segment1_workflowS2_decisiontree.png")
# Out:
# True

# %%
zero_one_table['Assessment Outcome - Successful'].value_counts()
# Out:
# 1    6335
# 0    3927
# Name: Assessment Outcome - Successful, dtype: int64

# %%
from sklearn.utils import resample

# Separate majority and minority classes
zero_one_table_majority = df[zero_one_table['Assessment Outcome - Successful']==1]
zero_one_table_minority = df[zero_one_table['Assessment Outcome - Successful']==0]

# Upsample minority class
df_majority_downsampled = resample(zero_one_table_majority,
                                 replace=False,     # sample with replacement
                                 n_samples=3927,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_downsampled = pd.concat([zero_one_table_minority, df_majority_downsampled])

# Display new class counts
df_downsampled = df_downsampled.fillna(0)
df_downsampled['Assessment Outcome - Successful'].value_counts()
# Out:
# 1    3927
# 0    3927
# Name: Assessment Outcome - Successful, dtype: int64

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

X=df_downsampled[features]
y=df_downsampled ['Assessment Outcome - Successful'] # Labels
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # 70% training and 30% test

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
# Setup the parameters and distributions to sample from: param_dist
param_dist = {"max_depth": [1, 2, 3, 4, 5, 6, 7, 8, 9],
"max_features": randint(1, 9),
"min_samples_leaf": randint(1, 9),
"criterion": ["gini", "entropy"]}
# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()
# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_dist, cv=5)
# Fit it to the data
tree_cv.fit(X_train,y_train)
# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 7, 'min_samples_leaf': 7}
# Best score is 0.6755517826825127

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 5,
                             random_state = 0)
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Generate the confusion matrix and classification report
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9083503054989817
# [[870  92]
#  [ 88 914]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       962
#            1       0.91      0.91      0.91      1002
#
#     accuracy                           0.91      1964
#    macro avg       0.91      0.91      0.91      1964
# weighted avg       0.91      0.91      0.91      1964

# %%
# DOT data
from IPython.display import Image
from sklearn import tree
import pydotplus
fn=features
cn=['0', '1']
# Create DOT data
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=fn,
                                class_names=cn,filled = True)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
# Show graph
Image(graph.create_png())

# %%
# Create PNG
graph.write_png("engineering_OF_segment1_workflowS2_decisiontree_downsampled.png")
# Out:
# True
