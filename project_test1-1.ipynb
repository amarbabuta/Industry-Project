# %% [markdown]
# ---
# Created on Tuesday Apr 15 2020
#
# MAST90106_2020_SM1-
# ---
# Data Science Project Pt1
# ---
# author: Zhaoying Chen

# %%
import pandas as pd
import csv

# %%
for i in ('gbk','utf-8','gb18030','ansi'):
    try:
        data = pd.read_csv('PG_Apps_Workflow_v17.csv',encoding=i)
        print(i+ 'decode success')
    except:
        print(i+ 'decode fail')
# Out:
# gbkdecode fail
# utf-8decode fail
# gb18030decode fail
# ansidecode fail

# %% [markdown]
# ---
# Since don't know which type of encode is original csv file's encoding, change the original file 'PG_Apps_Workflow_v17.csv' as 'PG_Apps_Workflow.csv'with utf-8 encoding. above step done in the local path.

# %%
UG_df = pd.DataFrame(pd.read_csv('UG_International.csv'))
PG_df = pd.DataFrame(pd.read_csv('PG_Apps_Workflow.csv'))
# Out:
# E:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (21,31,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# E:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (19,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
PG_df.shape
# Out:
# (1369204, 56)

# %%
PG_df.columns
# Out:
# Index(['CASE_ID', 'WRKFLW_TSK_MAP_GROUPED', 'WRKFLW_TSK_MAP_DETAILED',
#        'PATH_CRDATETIME', 'ITEM_CRUSER', 'WRKFLW_ORG_TYPE_CRUSER',
#        'STATUS_ORDER', 'LATEST_STATUS', 'WRKFLW_PROCESS', 'QUERY_PART',
#        'REFERRAL_ID', 'APPLICATION_ID', 'APPLICATION_LINE_ID', 'STU_ID',
#        'STU_CITIZEN_CD', 'STU_CITIZEN_NM', 'STU_BIRTH_DT', 'STU_ABOR_TSI_CD',
#        'STU_ABOR_TSI_NM', 'STU_BIRTH_CNTRY_CD', 'STU_BIRTH_CNTRY_NM',
#        'STU_CTZN_CNTRY_CD', 'STU_CTZN_CNTRY_NM', 'SUBMISSION_METHOD',
#        'ENTRY_TYPE', 'ASSESSMENT_DECISION_SCORE', 'ASSESSMENT_DECISION_NM',
#        'ASSESSMENT_OUTCOME_NM', 'LAST_COUNTRY_EDUCATION', 'PREV_INST_NM_MAIN',
#        'PREV_INST_NM_ALT1', 'PREV_INST_NM_ALT2', 'PREFERENCE_NO', 'SPK_CD',
#        'SPK_FULL_TITLE', 'ORG_UNIT_CD', 'AVAIL_ORG_UNIT_NM', 'SUPPORTING_ORG',
#        'STUDY_MODE_CD', 'RETURNING_DEFERRAL', 'CURR_AVAIL_YR',
#        'CURR_STUDY_PERIOD', 'CURR_SPRD_CD', 'CURR_SPRD_NM', 'ORIG_AVAIL_YR',
#        'ORIG_STUDY_PERIOD', 'ORIG_SPRD_CD', 'ORIG_SPRD_NM', 'SPK_CAT_TYPE_CD',
#        'BROAD_COURSE_LEVEL', 'DEGREETYPE', 'LIABILITY_CATEGORY_CD_RECODE',
#        'ORIG_LIABILITY_CATEGORY_CD_RECODE', 'OFFER_RELEASED_FG',
#        'OFFER_OUTCOME_CD', 'OFFER_CONDITIONS'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', 80)

# %%
PG_df.head(3)
# Out:
#               CASE_ID WRKFLW_TSK_MAP_GROUPED  \
# 0  809378|42892|53807  AR - Reviewed - Other
# 1  809378|42892|53807                 Cancel
# 2  809378|42892|53807   AR - Created - Other
#
#                              WRKFLW_TSK_MAP_DETAILED     PATH_CRDATETIME  \
# 0  AR - Reviewed - Acceptance agreement (Internat...   31/1/2019 9:13:08
# 1                                             Cancel  10/1/2019 11:02:31
# 2  AR - Created - Acceptance agreement (Internati...   7/1/2019 16:23:50
#
#   ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER LATEST_STATUS  \
# 0   MAHARJANS      Academic Services             1             Y
# 1  TECHONE-WS      Academic Services             2             N
# 2      MEREMA      Academic Services             3             N
#
#          WRKFLW_PROCESS                             QUERY_PART REFERRAL_ID  \
# 0  1. App to Assessment            Part 6 - Requirement Verify       Other
# 1         4. Post offer  Part 2 - Application Line ID Workflow         NaN
# 2  1. App to Assessment            Part 5 - Requirement Create       Other
#
#    APPLICATION_ID  APPLICATION_LINE_ID  STU_ID  STU_CITIZEN_CD  \
# 0           42892                53807  809378               4
# 1           42892                53807  809378               4
# 2           42892                53807  809378               4
#
#            STU_CITIZEN_NM       STU_BIRTH_DT STU_ABOR_TSI_CD STU_ABOR_TSI_NM  \
# 0  Temporary Entry Permit  24/6/1993 0:00:00             NaN     Not entered
# 1  Temporary Entry Permit  24/6/1993 0:00:00             NaN     Not entered
# 2  Temporary Entry Permit  24/6/1993 0:00:00             NaN     Not entered
#
#   STU_BIRTH_CNTRY_CD                STU_BIRTH_CNTRY_NM  STU_CTZN_CNTRY_CD  \
# 0               6101  China (excludes SARs and Taiwan)             6101.0
# 1               6101  China (excludes SARs and Taiwan)             6101.0
# 2               6101  China (excludes SARs and Taiwan)             6101.0
#
#                   STU_CTZN_CNTRY_NM   SUBMISSION_METHOD  \
# 0  China (excludes SARs and Taiwan)  Online Application
# 1  China (excludes SARs and Taiwan)  Online Application
# 2  China (excludes SARs and Taiwan)  Online Application
#
#                       ENTRY_TYPE  ASSESSMENT_DECISION_SCORE  \
# 0  Bachelor (equiv Aust 3yr deg)                       74.9
# 1  Bachelor (equiv Aust 3yr deg)                       74.9
# 2  Bachelor (equiv Aust 3yr deg)                       74.9
#
#   ASSESSMENT_DECISION_NM ASSESSMENT_OUTCOME_NM  \
# 0              Qualified            Successful
# 1              Qualified            Successful
# 2              Qualified            Successful
#
#              LAST_COUNTRY_EDUCATION  PREV_INST_NM_MAIN PREV_INST_NM_ALT1  \
# 0  China (excludes SARs and Taiwan)  Xiamen University               NaN
# 1  China (excludes SARs and Taiwan)  Xiamen University               NaN
# 2  China (excludes SARs and Taiwan)  Xiamen University               NaN
#
#   PREV_INST_NM_ALT2  PREFERENCE_NO SPK_CD  \
# 0               NaN              1  175AA
# 1               NaN              1  175AA
# 2               NaN              1  175AA
#
#                            SPK_FULL_TITLE  ORG_UNIT_CD AVAIL_ORG_UNIT_NM  \
# 0  Master of Arts and Cultural Management          100              Arts
# 1  Master of Arts and Cultural Management          100              Arts
# 2  Master of Arts and Cultural Management          100              Arts
#
#   SUPPORTING_ORG STUDY_MODE_CD RETURNING_DEFERRAL  CURR_AVAIL_YR  \
# 0            NaN           STD                  Y           2019
# 1            NaN           STD                  Y           2019
# 2            NaN           STD                  Y           2019
#
#    CURR_STUDY_PERIOD CURR_SPRD_CD       CURR_SPRD_NM  ORIG_AVAIL_YR  \
# 0  Start Year Intake         STYI  Start Year Intake           2016
# 1  Start Year Intake         STYI  Start Year Intake           2016
# 2  Start Year Intake         STYI  Start Year Intake           2016
#
#   ORIG_STUDY_PERIOD ORIG_SPRD_CD     ORIG_SPRD_NM SPK_CAT_TYPE_CD  \
# 0   Mid Year Intake         MDYI  Mid Year Intake             MCW
# 1   Mid Year Intake         MDYI  Mid Year Intake             MCW
# 2   Mid Year Intake         MDYI  Mid Year Intake             MCW
#
#   BROAD_COURSE_LEVEL   DEGREETYPE LIABILITY_CATEGORY_CD_RECODE  \
# 0               HDCW  Full Degree                           OF
# 1               HDCW  Full Degree                           OF
# 2               HDCW  Full Degree                           OF
#
#   ORIG_LIABILITY_CATEGORY_CD_RECODE OFFER_RELEASED_FG OFFER_OUTCOME_CD  \
# 0                                OF                 Y             $DEF
# 1                                OF                 Y             $DEF
# 2                                OF                 Y             $DEF
#
#   OFFER_CONDITIONS
# 0                Y
# 1                Y
# 2                Y

# %% [markdown]
# Construct 16 data frames based on 16 Departments
# ----
# __column name__ :'AVAIL_ORG_UNIT_NM'<br>
# __corresponding value__ : <br>
#     1\."Architecture, Building and Planning"<br>
#     2\."Arts"<br>
#     3\."Business and Economics"<br>
#     4\."Engineering"<br>
#     5\."Fine Arts and Music"<br>
#     6\."Law"<br>
#     7\."Medicine, Dentistry and Health Sciences"<br>
#     8\."Melbourne Business School"<br>
#     9\."Melbourne Graduate School of Education"<br>
#     10\."Melbourne School of Professional and Continuing Education"<br>
#     11\."Science"<br>
#     12\."Student and Scholarly Services"<br>
#     13\."UoM Commercial Ltd"<br>
#     14\."VCA and MCM"<br>
#     15\."Veterinary & Agricultural Sicences"<br>
#     16\."Veterinary and Agricultural Sicences"<br>

# %%
Architecture_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Architecture, Building and Planning"')
Arts_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Arts"')
Business_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Business and Economics"')
Engineering_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Engineering"')
Fine_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Fine Arts and Music"')
Law_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Law"')
Medicine_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Medicine, Dentistry and Health Sciences"')
BusinessSchool_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Melbourne Business School"')
GraduateSchoolEducation_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Melbourne Graduate School of Education"')
ProfessioinalContinuingEducation_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Melbourne School of Professional and Continuing Education"')
Science_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Science"')
StudentScholarlyServices_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Student and Scholarly Services"')
Commercial_df = PG_df.query('AVAIL_ORG_UNIT_NM == "UoM Commercial Ltd"')
VCA_MCM_df = PG_df.query('AVAIL_ORG_UNIT_NM == "VCA and MCM"')
Veterinary_Agricultural_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Veterinary & Agricultural Sciences"')
VeterinaryAndAgricultural_df = PG_df.query('AVAIL_ORG_UNIT_NM == "Veterinary and Agricultural Sciences"')

# %%
print("The dimension of Architecture,Building and Planning:",Architecture_df.shape)
print("The dimension of Arts",Arts_df.shape)
print("The dimension of Business and Economics:",Business_df.shape)
print("The dimension of Engineering",Engineering_df.shape)
print("The dimension of Fine Arts and Music:",Fine_df.shape)
print("The dimension of Law",Law_df.shape)
print("The dimension of Medicine, Dentistry and Health Sciences",Medicine_df.shape)
print("The dimension of Melbourne Business School:",BusinessSchool_df.shape)
print("The dimension of Melbourne Graduate School of Education:",GraduateSchoolEducation_df.shape)
print("The dimension of Melbourbe School of Professioinal and Contiuing Education:",ProfessioinalContinuingEducation_df.shape)
print("The dimension of Science:",Science_df.shape)
print("The dimension of Student and Scholarly Services:",StudentScholarlyServices_df.shape)
print("The dimension of UoM Commercial Ltd:",Commercial_df.shape)
print("The dimension of VCA and MCM:",VCA_MCM_df.shape)
print("The dimension of Veterinary & Agricultural Sciences:",Veterinary_Agricultural_df.shape)
print("The dimension of Veterinary and Agricultural Sciences:",VeterinaryAndAgricultural_df.shape)
# Out:
# The dimension of Architecture,Building and Planning: (71311, 56)
# The dimension of Arts (221812, 56)
# The dimension of Business and Economics: (229670, 56)
# The dimension of Engineering (233692, 56)
# The dimension of Fine Arts and Music: (9145, 56)
# The dimension of Law (73978, 56)
# The dimension of Medicine, Dentistry and Health Sciences (246412, 56)
# The dimension of Melbourne Business School: (9792, 56)
# The dimension of Melbourne Graduate School of Education: (118765, 56)
# The dimension of Melbourbe School of Professioinal and Contiuing Education: (2747, 56)
# The dimension of Science: (103289, 56)
# The dimension of Student and Scholarly Services: (2174, 56)
# The dimension of UoM Commercial Ltd: (287, 56)
# The dimension of VCA and MCM: (7848, 56)
# The dimension of Veterinary & Agricultural Sciences: (29840, 56)
# The dimension of Veterinary and Agricultural Sciences: (8442, 56)

# %%
Architecture_df.head(10)
# Out:
#                   CASE_ID  WRKFLW_TSK_MAP_GROUPED WRKFLW_TSK_MAP_DETAILED  \
# 195  351409|126853|209239                  Submit                  Submit
# 196  351409|126853|209239                Activate                Activate
# 197  351409|126853|209239           Release Offer           Release Offer
# 198  351409|126853|209239  Restart Offer Workflow  Restart Offer Workflow
# 199  351409|126853|209239                Finalise                Finalise
# 200  351409|126853|209239  Allow Workflow Restart  Allow Workflow Restart
# 201  351409|126853|209239       Ready to Finalise       Ready to Finalise
# 202  351409|126853|209239                   Defer                   Defer
# 203  351409|126853|209239           Release Offer           Release Offer
# 204  351409|126853|209239  Restart Offer Workflow  Restart Offer Workflow
#
#          PATH_CRDATETIME ITEM_CRUSER WRKFLW_ORG_TYPE_CRUSER  STATUS_ORDER  \
# 195   28/4/2018 19:12:44  $TB.DPUSER                    NaN             1
# 196   28/4/2018 19:12:44  $TB.DPUSER                    NaN             2
# 197  19/12/2017 11:39:11        SCRO      Academic Services             3
# 198  19/12/2017 11:39:08        SCRO      Academic Services             4
# 199  19/12/2017 11:39:00        SCRO      Academic Services             5
# 200  19/12/2017 11:39:00        SCRO      Academic Services             6
# 201  19/12/2017 11:38:50        SCRO      Academic Services             7
# 202   27/7/2017 10:54:31        SCRO      Academic Services             8
# 203   27/7/2017 10:54:25        SCRO      Academic Services             9
# 204   27/7/2017 10:54:05    MPDWHITE                Faculty            10
#
#     LATEST_STATUS        WRKFLW_PROCESS  \
# 195             Y  1. App to Assessment
# 196             N  1. App to Assessment
# 197             N         4. Post offer
# 198             N         4. Post offer
# 199             N         4. Post offer
# 200             N         4. Post offer
# 201             N         4. Post offer
# 202             N         4. Post offer
# 203             N         4. Post offer
# 204             N         4. Post offer
#
#                                 QUERY_PART REFERRAL_ID  APPLICATION_ID  \
# 195       Part 1 - Application ID Workflow         NaN          126853
# 196       Part 1 - Application ID Workflow         NaN          126853
# 197  Part 2 - Application Line ID Workflow         NaN          126853
# 198  Part 2 - Application Line ID Workflow         NaN          126853
# 199  Part 2 - Application Line ID Workflow         NaN          126853
# 200  Part 2 - Application Line ID Workflow         NaN          126853
# 201  Part 2 - Application Line ID Workflow         NaN          126853
# 202  Part 2 - Application Line ID Workflow         NaN          126853
# 203  Part 2 - Application Line ID Workflow         NaN          126853
# 204  Part 2 - Application Line ID Workflow         NaN          126853
#
#      APPLICATION_LINE_ID  STU_ID  STU_CITIZEN_CD STU_CITIZEN_NM  \
# 195               209239  351409               1     Australian
# 196               209239  351409               1     Australian
# 197               209239  351409               1     Australian
# 198               209239  351409               1     Australian
# 199               209239  351409               1     Australian
# 200               209239  351409               1     Australian
# 201               209239  351409               1     Australian
# 202               209239  351409               1     Australian
# 203               209239  351409               1     Australian
# 204               209239  351409               1     Australian
#
#           STU_BIRTH_DT STU_ABOR_TSI_CD STU_ABOR_TSI_NM STU_BIRTH_CNTRY_CD  \
# 195  29/3/1976 0:00:00               N              No               1100
# 196  29/3/1976 0:00:00               N              No               1100
# 197  29/3/1976 0:00:00               N              No               1100
# 198  29/3/1976 0:00:00               N              No               1100
# 199  29/3/1976 0:00:00               N              No               1100
# 200  29/3/1976 0:00:00               N              No               1100
# 201  29/3/1976 0:00:00               N              No               1100
# 202  29/3/1976 0:00:00               N              No               1100
# 203  29/3/1976 0:00:00               N              No               1100
# 204  29/3/1976 0:00:00               N              No               1100
#
#     STU_BIRTH_CNTRY_NM  STU_CTZN_CNTRY_CD STU_CTZN_CNTRY_NM  \
# 195          Australia             1100.0         Australia
# 196          Australia             1100.0         Australia
# 197          Australia             1100.0         Australia
# 198          Australia             1100.0         Australia
# 199          Australia             1100.0         Australia
# 200          Australia             1100.0         Australia
# 201          Australia             1100.0         Australia
# 202          Australia             1100.0         Australia
# 203          Australia             1100.0         Australia
# 204          Australia             1100.0         Australia
#
#       SUBMISSION_METHOD                     ENTRY_TYPE  \
# 195  Online Application  Bachelor (equiv Aust 3yr deg)
# 196  Online Application  Bachelor (equiv Aust 3yr deg)
# 197  Online Application  Bachelor (equiv Aust 3yr deg)
# 198  Online Application  Bachelor (equiv Aust 3yr deg)
# 199  Online Application  Bachelor (equiv Aust 3yr deg)
# 200  Online Application  Bachelor (equiv Aust 3yr deg)
# 201  Online Application  Bachelor (equiv Aust 3yr deg)
# 202  Online Application  Bachelor (equiv Aust 3yr deg)
# 203  Online Application  Bachelor (equiv Aust 3yr deg)
# 204  Online Application  Bachelor (equiv Aust 3yr deg)
#
#      ASSESSMENT_DECISION_SCORE ASSESSMENT_DECISION_NM ASSESSMENT_OUTCOME_NM  \
# 195                       67.0              Qualified            Successful
# 196                       67.0              Qualified            Successful
# 197                       67.0              Qualified            Successful
# 198                       67.0              Qualified            Successful
# 199                       67.0              Qualified            Successful
# 200                       67.0              Qualified            Successful
# 201                       67.0              Qualified            Successful
# 202                       67.0              Qualified            Successful
# 203                       67.0              Qualified            Successful
# 204                       67.0              Qualified            Successful
#
#     LAST_COUNTRY_EDUCATION        PREV_INST_NM_MAIN        PREV_INST_NM_ALT1  \
# 195              Australia  University of Melbourne  University of Melbourne
# 196              Australia  University of Melbourne  University of Melbourne
# 197              Australia  University of Melbourne  University of Melbourne
# 198              Australia  University of Melbourne  University of Melbourne
# 199              Australia  University of Melbourne  University of Melbourne
# 200              Australia  University of Melbourne  University of Melbourne
# 201              Australia  University of Melbourne  University of Melbourne
# 202              Australia  University of Melbourne  University of Melbourne
# 203              Australia  University of Melbourne  University of Melbourne
# 204              Australia  University of Melbourne  University of Melbourne
#
#     PREV_INST_NM_ALT2  PREFERENCE_NO   SPK_CD      SPK_FULL_TITLE  \
# 195               NaN              1  MC-PROP  Master of Property
# 196               NaN              1  MC-PROP  Master of Property
# 197               NaN              1  MC-PROP  Master of Property
# 198               NaN              1  MC-PROP  Master of Property
# 199               NaN              1  MC-PROP  Master of Property
# 200               NaN              1  MC-PROP  Master of Property
# 201               NaN              1  MC-PROP  Master of Property
# 202               NaN              1  MC-PROP  Master of Property
# 203               NaN              1  MC-PROP  Master of Property
# 204               NaN              1  MC-PROP  Master of Property
#
#      ORG_UNIT_CD                    AVAIL_ORG_UNIT_NM SUPPORTING_ORG  \
# 195          702  Architecture, Building and Planning            NaN
# 196          702  Architecture, Building and Planning            NaN
# 197          702  Architecture, Building and Planning            NaN
# 198          702  Architecture, Building and Planning            NaN
# 199          702  Architecture, Building and Planning            NaN
# 200          702  Architecture, Building and Planning            NaN
# 201          702  Architecture, Building and Planning            NaN
# 202          702  Architecture, Building and Planning            NaN
# 203          702  Architecture, Building and Planning            NaN
# 204          702  Architecture, Building and Planning            NaN
#
#     STUDY_MODE_CD RETURNING_DEFERRAL  CURR_AVAIL_YR  CURR_STUDY_PERIOD  \
# 195           STD                  Y           2019  Start Year Intake
# 196           STD                  Y           2019  Start Year Intake
# 197           STD                  Y           2019  Start Year Intake
# 198           STD                  Y           2019  Start Year Intake
# 199           STD                  Y           2019  Start Year Intake
# 200           STD                  Y           2019  Start Year Intake
# 201           STD                  Y           2019  Start Year Intake
# 202           STD                  Y           2019  Start Year Intake
# 203           STD                  Y           2019  Start Year Intake
# 204           STD                  Y           2019  Start Year Intake
#
#     CURR_SPRD_CD       CURR_SPRD_NM  ORIG_AVAIL_YR ORIG_STUDY_PERIOD  \
# 195         STYI  Start Year Intake           2016   Mid Year Intake
# 196         STYI  Start Year Intake           2016   Mid Year Intake
# 197         STYI  Start Year Intake           2016   Mid Year Intake
# 198         STYI  Start Year Intake           2016   Mid Year Intake
# 199         STYI  Start Year Intake           2016   Mid Year Intake
# 200         STYI  Start Year Intake           2016   Mid Year Intake
# 201         STYI  Start Year Intake           2016   Mid Year Intake
# 202         STYI  Start Year Intake           2016   Mid Year Intake
# 203         STYI  Start Year Intake           2016   Mid Year Intake
# 204         STYI  Start Year Intake           2016   Mid Year Intake
#
#     ORIG_SPRD_CD     ORIG_SPRD_NM SPK_CAT_TYPE_CD BROAD_COURSE_LEVEL  \
# 195         MDYI  Mid Year Intake             MCW               HDCW
# 196         MDYI  Mid Year Intake             MCW               HDCW
# 197         MDYI  Mid Year Intake             MCW               HDCW
# 198         MDYI  Mid Year Intake             MCW               HDCW
# 199         MDYI  Mid Year Intake             MCW               HDCW
# 200         MDYI  Mid Year Intake             MCW               HDCW
# 201         MDYI  Mid Year Intake             MCW               HDCW
# 202         MDYI  Mid Year Intake             MCW               HDCW
# 203         MDYI  Mid Year Intake             MCW               HDCW
# 204         MDYI  Mid Year Intake             MCW               HDCW
#
#       DEGREETYPE LIABILITY_CATEGORY_CD_RECODE  \
# 195  Full Degree                           AS
# 196  Full Degree                           AS
# 197  Full Degree                           AS
# 198  Full Degree                           AS
# 199  Full Degree                           AS
# 200  Full Degree                           AS
# 201  Full Degree                           AS
# 202  Full Degree                           AS
# 203  Full Degree                           AS
# 204  Full Degree                           AS
#
#     ORIG_LIABILITY_CATEGORY_CD_RECODE OFFER_RELEASED_FG OFFER_OUTCOME_CD  \
# 195                                AF                 Y              NaN
# 196                                AF                 Y              NaN
# 197                                AF                 Y              NaN
# 198                                AF                 Y              NaN
# 199                                AF                 Y              NaN
# 200                                AF                 Y              NaN
# 201                                AF                 Y              NaN
# 202                                AF                 Y              NaN
# 203                                AF                 Y              NaN
# 204                                AF                 Y              NaN
#
#     OFFER_CONDITIONS
# 195                N
# 196                N
# 197                N
# 198                N
# 199                N
# 200                N
# 201                N
# 202                N
# 203                N
# 204                N
